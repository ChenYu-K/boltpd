# %%
import numpy
import pandas as pd
import torch
import numpy as np
#from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import TensorDataset, DataLoader
import os,random
import torchvision.transforms as T
import csv
import cv2
from torch.utils.data import Dataset
from torchvision import transforms
import torch.nn.functional as F
from PIL import Image
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.autograd import Variable
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import seaborn as sns
from scipy.fft import fft2, ifft2, fftshift
#my imports

import train

from torch.utils.tensorboard import SummaryWriter #tensorboard --logdir log --bind_all

# %%
current_directory = os.getcwd()
print("当前路径:", current_directory)

import torch

print(torch.__version__)
print(torch.cuda.is_available())

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# x = torch.tensor([1, 2, 3]).to(device)
# print(x.device)
# Out:
# 当前路径: /home/br-python/Documents/chen/boltpd
# 2.0.0+cu117
# True

# %%
def classify_force(force):
        # 将轴力分为10个单位一类的标签，并确保标签在0-23之间
        return min(int(force // 10), 23)

label=classify_force(125)
print(label)
# Out:
# 12

# %%
import cv2
def generate_dataset(dir):
    """
    set_label should be 'torch.tensor([1])' if two-catogory and positive sample
    """
    pathDir = os.listdir(dir)    #取图片的原始路径
    filenumber=len(pathDir)
    rate=1    #自定义抽取图片的比例，比方说100张抽10张，那就是0.1
    picknumber=int(filenumber*rate) #按照rate比例从文件夹中取一定数量图片
    sample = random.sample(pathDir, picknumber)  #随机选取picknumber数量的样本图片

    file = pd.read_csv(r'./label/AI-bolt-color-202404-inkan.csv') # 读取csv数据
    file=np.array(file)#注意数据会跳过第一行，第一行为索引标题
    labels=[]
    img_data = []
    f0 = None
    def classify_force(force):
        # 将轴力分为10个单位一类的标签
        return min((force // 10) ,23)

    for file_name in sample:
        if f0 is None:
            f0 = os.path.join(dir, file_name)
        if file_name != "Thumbs.db":
            if int(file_name[-9:-4]) > 2097 and int(file_name[-9:-4]) < 3597:
                img_dir = os.path.join(dir, file_name)
                img = cv2.imread(img_dir, cv2.IMREAD_GRAYSCALE)
                ref_img = cv2.imread('database/202404-inkan/output-resize/DSC02098.JPG', cv2.IMREAD_GRAYSCALE)

                # Apply Fourier Transform to both images
                f_transform_initial = fft2(img)
                f_shift_initial = fftshift(f_transform_initial)
                phase_spectrum_initial = np.angle(f_shift_initial)

                f_transform_ref = fft2(ref_img)
                f_shift_ref = fftshift(f_transform_ref)
                phase_spectrum_ref = np.angle(f_shift_ref)

                # Subtract the phase spectrum of the reference image from the initial image
                phase_spectrum_diff = phase_spectrum_initial - phase_spectrum_ref

                # Apply a high-pass filter to the phase difference (optional)
                rows, cols = image.shape
                crow, ccol = rows // 2 , cols // 2
                mask = np.ones((rows, cols), np.uint8)
                r = 30  # Radius of the high-pass filter
                center = [crow, ccol]
                x, y = np.ogrid[:rows, :cols]
                mask_area = (x - center[0]) ** 2 + (y - center[1]) ** 2 <= r*r
                mask[mask_area] = 0

                # Apply the mask
                f_shift_diff = fftshift(fft2(phase_spectrum_diff)) * mask

                ## Reconstruct the image using the phase spectrum difference
                #f_transform_diff = np.abs(f_shift_initial) * np.exp(1j * phase_spectrum_diff)

                # Inverse Fourier Transform
                img_diff_pa = np.abs(ifft2(ifftshift(f_shift_diff )))

                img_data.append(img_diff_pa)
                #img_data.append(file_name)
                for item in file:       #add label, from 1row
                    sh = item[1]
                    if file_name[-9:-4] == sh[-9:-4]:
                        force = item[0]
                        label = classify_force(force)
                        labels.append(label)
    # 将标签转换为one-hot编码
    labels = torch.tensor(labels, dtype=torch.long)
    #labels = torch.nn.functional.one_hot(labels, num_classes=24)  # 23类分类，外加1类(即24类)
    return img_data, labels

class MyDataset(Dataset):
    def __init__(self, data, labels, transform=None, target_transform=None):
        self.transform = transform
        self.target_transform = target_transform
        imgs = []
        for i in range(len(labels)):
            # print(type(data[i]))    # <class 'PIL.Image.Image'>
            im_tensor = transform(data[i]) #.to(torch.device("cpu"))
            imgs.append((im_tensor, labels[i]))
        self.imgs = imgs                         # DataLoader通过getitem读取图片数据
    def __getitem__(self, index):
        fn, label = self.imgs[index]
        return fn, label
    def __len__(self):
        return len(self.imgs)

# %%
import os
import random
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from PIL import Image
import cv2

# Custom transform for adding Gaussian noise
class AddGaussianNoise(object):
    def __init__(self, mean=0.0, std=1.0):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        noise = torch.randn(tensor.size()) * self.std + self.mean
        return tensor + noise

    def __repr__(self):
        return f'{self.__class__.__name__}(mean={self.mean}, std={self.std})'

# Data augmentation transform
augment_transform = transforms.Compose([
    transforms.Resize(1200),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(20),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    AddGaussianNoise(mean=0.0, std=0.1),
    transforms.Normalize((0.5,), (0.5,))
])

# Original transform
original_transform = transforms.Compose([
    transforms.Resize(1200),
    transforms.CenterCrop(800),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

def generate_augmented_dataset(dir, csv_file, augment_times=5):
    pathDir = os.listdir(dir)
    filenumber = len(pathDir)
    sample = random.sample(pathDir, filenumber)
    
    file = pd.read_csv(csv_file)
    file = np.array(file)
    labels = []
    img_data = []

    def classify_force(force):
        return min((force // 10), 23)

    for file_name in sample:
        if file_name != "Thumbs.db":
            if int(file_name[-9:-4]) > 2097 and int(file_name[-9:-4]) < 3597:
                img_dir = os.path.join(dir, file_name)
                img = cv2.imread(img_dir, cv2.IMREAD_GRAYSCALE)
                ref_img = cv2.imread('database/202404-inkan/output-resize/DSC02098.JPG', cv2.IMREAD_GRAYSCALE)

                # Apply Fourier Transform to both images
                f_transform_initial = fft2(img)
                f_shift_initial = fftshift(f_transform_initial)
                phase_spectrum_initial = np.angle(f_shift_initial)

                f_transform_ref = fft2(ref_img)
                f_shift_ref = fftshift(f_transform_ref)
                phase_spectrum_ref = np.angle(f_shift_ref)

                # Subtract the phase spectrum of the reference image from the initial image
                phase_spectrum_diff = phase_spectrum_initial - phase_spectrum_ref

                # Apply a high-pass filter to the phase difference (optional)
                rows, cols = img.shape
                crow, ccol = rows // 2 , cols // 2
                mask = np.ones((rows, cols), np.uint8)
                r = 30  # Radius of the high-pass filter
                center = [crow, ccol]
                x, y = np.ogrid[:rows, :cols]
                mask_area = (x - center[0]) ** 2 + (y - center[1]) ** 2 <= r*r
                mask[mask_area] = 0

                # Apply the mask
                f_shift_diff = fftshift(fft2(phase_spectrum_diff)) * mask

                ## Reconstruct the image using the phase spectrum difference
                #f_transform_diff = np.abs(f_shift_initial) * np.exp(1j * phase_spectrum_diff)

                # Inverse Fourier Transform
                img_diff_pa = np.abs(ifft2(fftshift(f_shift_diff )))

                pimg = Image.fromarray(img_diff_pa)
                pimg = original_transform(pimg)
                img_data.append(pimg)

                for item in file:
                    sh = item[1]
                    if file_name[-9:-4] == sh[-9:-4]:
                        force = item[0]
                        label = classify_force(force)
                        labels.extend([label] * (augment_times + 1))
    
    labels = torch.tensor(labels, dtype=torch.long)
    return img_data, labels

class MyDataset(Dataset):
    def __init__(self, data, labels, transform=None, target_transform=None):
        self.transform = transform
        self.target_transform = target_transform
        self.imgs = list(zip(data, labels))

    def __getitem__(self, index):
        fn, label = self.imgs[index]
        return fn, label

    def __len__(self):
        return len(self.imgs)

traindir = 'database/202404-inkan/output-resize/'
validdir = 'database/202404-inkan/valid-or/'
csv_file = './label/AI-bolt-color-202404-inkan.csv'

train_rdata, train_label = generate_augmented_dataset(traindir, csv_file, augment_times=0)
valid_rdata, valid_label = generate_augmented_dataset(validdir, csv_file, augment_times=0)

train_data = MyDataset(train_rdata, train_label)
valid_data = MyDataset(valid_rdata, valid_label)

train_loader = DataLoader(dataset=train_data, batch_size=1, shuffle=True)
valid_loader = DataLoader(dataset=valid_data, batch_size=1, shuffle=True)

# %%
print(len(train_rdata), len(train_label))
print(len(valid_rdata), len(valid_label))
dataiter=iter(train_loader)
images, labels = dataiter.__next__()
print(images.shape)
print(labels)
print(labels.shape)
topic = T.ToPILImage()
imm1 = topic(images[0])
vimg, vlabels = dataiter.__next__()
plt.imshow(topic(vimg[0]))
# Out:
# 1194 1194
# 305 305
# torch.Size([1, 1, 800, 800])
# tensor([8])
# torch.Size([1])

# %% [markdown]
# # defin model

# %%
class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid())

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y
    
class Bottleneck(nn.Module):
    """
    __init__
        in_channel：残差块输入通道数
        out_channel：残差块输出通道数
        stride：卷积步长
        downsample：在_make_layer函数中赋值，用于控制shortcut图片下采样 H/2 W/2
    """
    expansion = 4   # 残差块第3个卷积层的通道膨胀倍率
    def __init__(self, in_channel, out_channel, stride=1, downsample=None):
        super(Bottleneck, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=in_channel, out_channels=out_channel, kernel_size=1, stride=1, bias=False)   # H,W不变。C: in_channel -> out_channel
        self.bn1 = nn.BatchNorm2d(num_features=out_channel)
        self.conv2 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel, kernel_size=3, stride=stride, bias=False, padding=1)  # H/2，W/2。C不变
        self.bn2 = nn.BatchNorm2d(num_features=out_channel)
        self.conv3 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel*self.expansion, kernel_size=1, stride=1, bias=False)   # H,W不变。C: out_channel -> 4*out_channel
        self.bn3 = nn.BatchNorm2d(num_features=out_channel*self.expansion)
        self.relu = nn.ReLU(inplace=True)
        # Add SEBlock
        self.seblock = SEBlock(out_channel*self.expansion)
        self.downsample = downsample
    
    def forward(self, x):
        identity = x    # 将原始输入暂存为shortcut的输出
        if self.downsample is not None:
            identity = self.downsample(x)   # 如果需要下采样，那么shortcut后:H/2，W/2。C: out_channel -> 4*out_channel(见ResNet中的downsample实现)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)

        out = self.conv3(out)
        out = self.bn3(out)

        #Apply SEBlock
        out = self.seblock(out)

        out += identity     # 残差连接0 n
        out = self.relu(out)

        return out


class ModResdic(nn.Module):
    """
    __init__
        block: 堆叠的基本模块
        block_num: 基本模块堆叠个数,是一个list,对于resnet50=[3,4,6,3]
        num_classes: 全连接之后的分类特征维度

    _make_layer
        block: 堆叠的基本模块
        channel: 每个stage中堆叠模块的第一个卷积的卷积核个数，对resnet50分别是:64,128,256,512
        block_num: 当期stage堆叠block个数
        stride: 默认卷积步长
    """
    def __init__(self, block, block_num, num_classes, num_attention_heads=4):
        super(ModResdic, self).__init__()
        self.in_channel = 64    # conv1的输出维度
        self.conv1 = nn.Conv2d(in_channels=2, out_channels=self.in_channel, kernel_size=7, stride=2, padding=3, bias=False)     # H/2,W/2。C:3->64
        self.bn1 = nn.BatchNorm2d(self.in_channel)
        self.relu = nn.ReLU(inplace=True)
        self.activation = nn.LeakyReLU(negative_slope=0.01)
        self.sigmoid = nn.Sigmoid()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)     # H/2,W/2。C不变
        self.layer1 = self._make_layer(block=block, channel=64, block_num=block_num[0], stride=1)   # H,W不变。downsample控制的shortcut，out_channel=64x4=256
        self.layer2 = self._make_layer(block=block, channel=128, block_num=block_num[1], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=128x4=512
        self.layer3 = self._make_layer(block=block, channel=256, block_num=block_num[2], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=256x4=1024
        self.layer4 = self._make_layer(block=block, channel=512, block_num=block_num[3], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=512x4=2048

        # 添加自注意力层
        self.self_attention = nn.MultiheadAttention(embed_dim=2048, num_heads=num_attention_heads)

        # Add SEBlocks after each residual block in the feature extraction layers
        self.seblock1 = SEBlock(64 * block.expansion)
        self.seblock2 = SEBlock(128 * block.expansion)
        self.seblock3 = SEBlock(256 * block.expansion)
        self.seblock4 = SEBlock(512 * block.expansion)

        self.fusion4 = MultiScaleFusion(1024 * block.expansion)
        self.fusion3 = MultiScaleFusion(512 * block.expansion)
        self.fusion2 = MultiScaleFusion(256 * block.expansion)
        self.fusion1 = MultiScaleFusion(128 * block.expansion)

        self.avgpool = nn.AdaptiveAvgPool2d((1,1))  # 将每张特征图大小->(1,1)，则经过池化后的输出维度=通道数
        self.fc1 = nn.Linear(in_features=512*block.expansion, out_features=1024) #in=2048,out=1024
        self.dropout = nn.Dropout(0.8) #dropout rate
        self.fc2 = nn.Linear(in_features=2048, out_features=1024) #in=1024, out=1
        self.fc3 = nn.Linear(in_features=1024, out_features=num_classes) #in=512, out=1
        #self.fc4 = nn.Linear(in_features=64, out_features=num_classes) #in=128, out=1

        self.fc = nn.Linear(512 * block.expansion, num_classes)

        # Upsampling layers for feature fusion
        self.upsample = lambda x: nn.functional.interpolate(x, scale_factor=2, mode='bilinear', align_corners=None).to(x.device)
        #self.upsample = nn.functional.interpolate(scale_factor=2, mode='bilinear', align_corners=True)
        
        for m in self.modules():    # 权重初始化
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

    def _make_layer(self, block, channel, block_num, stride=1):
        downsample = None   # 用于控制shorcut路的
        if stride != 1 or self.in_channel != channel*block.expansion:   # 对resnet50：conv2中特征图尺寸H,W不需要下采样/2，但是通道数x4，因此shortcut通道数也需要x4。对其余conv3,4,5，既要特征图尺寸H,W/2，又要shortcut维度x4
            downsample = nn.Sequential(
                nn.Conv2d(in_channels=self.in_channel, out_channels=channel*block.expansion, kernel_size=1, stride=stride, bias=False), # out_channels决定输出通道数x4，stride决定特征图尺寸H,W/2
                nn.BatchNorm2d(num_features=channel*block.expansion))

        layers = []  # 每一个convi_x的结构保存在一个layers列表中，i={2,3,4,5}
        layers.append(block(in_channel=self.in_channel, out_channel=channel, downsample=downsample, stride=stride)) # 定义convi_x中的第一个残差块，只有第一个需要设置downsample和stride
        self.in_channel = channel*block.expansion   # 在下一次调用_make_layer函数的时候，self.in_channel已经x4

        for _ in range(1, block_num):  # 通过循环堆叠其余残差块(堆叠了剩余的block_num-1个)
            layers.append(block(in_channel=self.in_channel, out_channel=channel))

        return nn.Sequential(*layers)   # '*'的作用是将list转换为非关键字参数传入

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.activation(x)
        x = self.maxpool(x)

        x1 = self.layer1(x)
        x1 = self.fusion1(x1)
        x1 = self.seblock1(x1)
        x2 = self.layer2(x1)
        #x2 = self.seblock2(x2)
        #x2 = self.fusion2(x2)
        x3 = self.layer3(x2)
        #x3 = self.seblock3(x3)
        #x3 = self.fusion3(x3)
        x4 = self.layer4(x3)
        x4 = self.seblock4(x4)
        x4 = self.fusion4(x4)

        x = self.avgpool(x4)
        x = torch.flatten(x, 1)

        # 添加自注意力层
        x, _ = self.self_attention(x.unsqueeze(0), x.unsqueeze(0), x.unsqueeze(0))
        x = x.squeeze(0)  # 移除添加的维度以适应全连接层的输入要求

        #x = x.unsqueeze(0)  # 添加一个维度以适应自注意力层的输入要求
        #x, _ = self.self_attention(x, x, x)
        
        #x = self.relu(self.fc1(x))
        #x = self.relu(self.fc2(x))
        #x = self.dropout(x)
        x = self.fc3(x)

        return x

class MultiScaleFusion(nn.Module):
    def __init__(self,out_channels):
        super(MultiScaleFusion, self).__init__()
        self.conv1 = nn.Conv2d(out_channels, out_channels, kernel_size=1, stride=1, padding=0)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(out_channels, out_channels, kernel_size=5, stride=1, padding=2)
        # 定义融合的卷积层
        self.fusion_conv = nn.Conv2d(4*out_channels, out_channels, kernel_size=1)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x1 = self.conv1(x)
        x2 = self.conv2(x)
        x3 = self.conv3(x)
        out = torch.cat([x,x1, x2, x3], dim=1)
        # 对融合的特征图进行卷积操作
        out = self.fusion_conv(out)
        out = self.bn(out)
        out = self.relu(out)
        return out
    
class ModResv2(nn.Module):
    """
    __init__
        block: 堆叠的基本模块
        block_num: 基本模块堆叠个数,是一个list,对于resnet50=[3,4,6,3]
        num_classes: 全连接之后的分类特征维度

    _make_layer
        block: 堆叠的基本模块
        channel: 每个stage中堆叠模块的第一个卷积的卷积核个数，对resnet50分别是:64,128,256,512
        block_num: 当期stage堆叠block个数
        stride: 默认卷积步长
    """
    def __init__(self, block, block_num, num_classes, num_attention_heads=4):
        super(ModResv2, self).__init__()
        self.in_channel = 64    # conv1的输出维度

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=self.in_channel, kernel_size=7, stride=2, padding=3, bias=False)     # H/2,W/2。C:3->64
        self.bn1 = nn.BatchNorm2d(self.in_channel)
        self.relu = nn.ReLU(inplace=True)
        self.activation = nn.LeakyReLU(negative_slope=0.01)
        self.sigmoid = nn.Sigmoid()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)     # H/2,W/2。C不变
        self.layer1 = self._make_layer(block=block, channel=64, block_num=block_num[0], stride=1)   # H,W不变。downsample控制的shortcut，out_channel=64x4=256
        self.layer2 = self._make_layer(block=block, channel=128, block_num=block_num[1], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=128x4=512
        self.layer3 = self._make_layer(block=block, channel=256, block_num=block_num[2], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=256x4=1024
        self.layer4 = self._make_layer(block=block, channel=512, block_num=block_num[3], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=512x4=2048
        
        self.self_attention = nn.MultiheadAttention(embed_dim=2048, num_heads=num_attention_heads)

        # Add SEBlocks after each residual block in the feature extraction layers
        self.seblock1 = SEBlock(64 * block.expansion)
        self.seblock2 = SEBlock(128 * block.expansion)
        self.seblock3 = SEBlock(256 * block.expansion)
        self.seblock4 = SEBlock(512 * block.expansion)

        self.fusion4 = MultiScaleFusion(512 * block.expansion)
        #self.fusion3 = MultiScaleFusion(256 * block.expansion)
        #self.fusion2 = MultiScaleFusion(128 * block.expansion)
        self.fusion1 = MultiScaleFusion(64 * block.expansion)


        self.avgpool = nn.AdaptiveAvgPool2d((1,1))  # 将每张特征图大小->(1,1)，则经过池化后的输出维度=通道数
        self.fc1 = nn.Linear(in_features=512*block.expansion, out_features=1024) #in=2048,out=1024
        self.dropout = nn.Dropout(0.6) #dropout rate
        self.fc2 = nn.Linear(in_features=1024, out_features=num_classes) #in=1024, out=1
        #self.fc3 = nn.Linear(in_features=512, out_features=num_classes) #in=512, out=1
        #self.fc4 = nn.Linear(in_features=64, out_features=num_classes) #in=128, out=1
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        # Upsampling layers for feature fusion
        self.upsample = lambda x: nn.functional.interpolate(x, scale_factor=2, mode='bilinear', align_corners=None).to(x.device)
        #self.upsample = nn.functional.interpolate(scale_factor=2, mode='bilinear', align_corners=True)
        
        for m in self.modules():    # 权重初始化
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

    def _make_layer(self, block, channel, block_num, stride=1):
        downsample = None   # 用于控制shorcut路的
        if stride != 1 or self.in_channel != channel*block.expansion:   # 对resnet50：conv2中特征图尺寸H,W不需要下采样/2，但是通道数x4，因此shortcut通道数也需要x4。对其余conv3,4,5，既要特征图尺寸H,W/2，又要shortcut维度x4
            downsample = nn.Sequential(
                nn.Conv2d(in_channels=self.in_channel, out_channels=channel*block.expansion, kernel_size=1, stride=stride, bias=False), # out_channels决定输出通道数x4，stride决定特征图尺寸H,W/2
                nn.BatchNorm2d(num_features=channel*block.expansion))

        layers = []  # 每一个convi_x的结构保存在一个layers列表中，i={2,3,4,5}
        layers.append(block(in_channel=self.in_channel, out_channel=channel, downsample=downsample, stride=stride)) # 定义convi_x中的第一个残差块，只有第一个需要设置downsample和stride
        self.in_channel = channel*block.expansion   # 在下一次调用_make_layer函数的时候，self.in_channel已经x4

        for _ in range(1, block_num):  # 通过循环堆叠其余残差块(堆叠了剩余的block_num-1个)
            layers.append(block(in_channel=self.in_channel, out_channel=channel))

        return nn.Sequential(*layers)   # '*'的作用是将list转换为非关键字参数传入

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x1 = self.layer1(x)
        x1 = self.seblock1(x1)
        x1 = self.fusion1(x1)
        x2 = self.layer2(x1)
        x2 = self.seblock2(x2)
        x3 = self.layer3(x2)
        x3 = self.seblock3(x3)
        x4 = self.layer4(x3)
        x4 = self.seblock4(x4)
        x4 = self.fusion4(x4)

        x = self.avgpool(x4)
        x = torch.flatten(x, 1)

        # 添加自注意力层
        x, _ = self.self_attention(x.unsqueeze(0), x.unsqueeze(0), x.unsqueeze(0))
        x = x.squeeze(0) 

        #x = self.activation(self.fc1(x))
        x = self.dropout(x)
        #x = self.activation(self.fc2(x))
        x = self.fc(x)

        return x

# %%
def testAccuracy(net, epoch, device):
    net.eval()
    accuracy = 0.0
    total = 0.0
    with torch.no_grad():
        for i, (images, labels) in enumerate(valid_loader, 0):
            images = images.to(device)
            labels = labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            accuracy += (predicted == labels).sum().item()

    accuracy = accuracy / total
    print('Accuracy: ', accuracy)
    writer.add_scalar('Valid-ACC', accuracy, epoch + 1)
    return accuracy

def valid(model, device, valid_loader, classes):
    model.eval()
    all_labels = []
    all_predictions = []
    
    with torch.no_grad():
        for images, labels in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    # 计算各项指标
    accuracy = accuracy_score(all_labels, all_predictions)
    precision = precision_score(all_labels, all_predictions, average='weighted', labels=np.arange(24))
    recall = recall_score(all_labels, all_predictions, average='weighted', labels=np.arange(24))
    f1 = f1_score(all_labels, all_predictions, average='weighted', labels=np.arange(24))
    conf_matrix = confusion_matrix(all_labels, all_predictions, labels=np.arange(24))
    class_report = classification_report(all_labels, all_predictions, target_names=classes, labels=np.arange(24))

    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print('\nClassification Report:\n', class_report)

    # 绘制混淆矩阵
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

    return accuracy, precision, recall, f1, conf_matrix, class_report

def train(num_epochs,device,net):
    import time
    start_time = time.process_time()
    best_accuracy = 0.0

    k=0
    predata=[]
    labeldata=[]
    mseloss=[]
    trainnum=[]
    epochout=[]
    epochV=[]
    vloss=[]
    vr2=[]
    # Convert model parameters and buffers to CPU or Cuda
    net.to(device)
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        running_loss = 0.0
        running_corrects = 0.0
        total_samples = 0

        for i, (images, labels) in enumerate(train_loader, 0):
            images = Variable(images.to(device))
            labels = Variable(labels.to(device))
            optimizer.zero_grad()
            prediction = net(images)
            loss = loss_func(prediction, labels)*100
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            _, predicted = torch.max(prediction.data, 1)
            running_corrects += (predicted == labels).sum().item()
            total_samples += labels.size(0)
            
            if (i+1) % 10 == 0:
                avg_loss = running_loss / 10
                avg_acc = running_corrects / total_samples
                
                print(f'[Epoch: {epoch+1}/{num_epochs}] - Step: {i+1}/{len(train_loader)} | Loss: {avg_loss:.3f} | Accuracy: {avg_acc:.3f}')

                mseloss.append(running_loss/10)
                trainnum.append(i+1)
                epochout.append(epoch+1)
                result=pd.DataFrame({'epoch':epochout,'trainnum':trainnum,'loss':mseloss})
                result.to_csv("./result/"+casename+"/"+casename+"-result.csv",index=False,sep=',')

                # Tensorboard
                writer.add_scalar('Training loss', avg_loss, epoch * len(train_loader) + i)
                writer.add_scalar('ACC', avg_acc, epoch * len(train_loader) + i)

                # zero the loss
                running_loss = 0.0
                running_corrects = 0.0
                total_samples = 0

            predata.append(prediction.data.cpu().numpy()[0])
            labeldata.append(labels.data.cpu().numpy()[0])

        valid_accuracy = testAccuracy(net, epoch, device)
        if valid_accuracy > best_accuracy:
            best_accuracy = valid_accuracy
            torch.save(net.state_dict(), 'best_model.pth')
            print('Model saved!')

    end_time = time.process_time()
    print("Training completed in: ", (end_time - start_time) / 3600, " hours")

def predict(net, device, dataloader):
    net.to(device)
    net.eval()
    predictions = []
    labels = []
    with torch.no_grad():
        for images, labels_batch in dataloader:
            images = images.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            predictions.extend(predicted.cpu().numpy())
            labels.extend(labels_batch.cpu().numpy())
    return predictions, labels

# %% [markdown]
# # 超参数Parameter

# %%
#from net import ResNet, Bottleneck
#from SEBlock import SEBlock
from loss_func import HuberLossPena

classes = [f'{i*10}-{i*10+10}' for i in range(24)]
    
# 输入输出的数据维度，这里都是1维
INPUT_FEATURE_DIM = 5000
# 隐含层中神经元的个数
#NEURON_NUM = 500
#OUTPUT_FEATURE_DIM = 1
# 学习率，越大学的越快，但也容易造成不稳定，准确率上下波动的情况
LEARNING_RATE = 2e-8

# 定义模型
net = ModResv2(block=Bottleneck, block_num=[3,4,6,3],num_classes=24) #152 (3,4,36,3)

# 训练网络
# 这里也可以使用其它的优化方法
optimizer = torch.optim.Adam(net.parameters(), lr=LEARNING_RATE)
#optimizer = torch.optim.SGD(net.parameters(),lr=LEARNING_RATE)
# 定义一个误差计算方法
#loss_func = HuberLossPena(delta=0.1, penalty_weight=5.0)
#loss_func = nn.MSELoss()
loss_func = nn.CrossEntropyLoss() #定义交叉熵损失函数 交叉熵损失函数是用来衡量两个概率分布之间的距离的#nn.MSELoss()
# Define the loss function with Classification Cross-Entropy loss and an optimizer with Adam optimizer


casename='202406-diffpa'
os.makedirs("./log/"+casename)
os.makedirs("./result/"+casename)
writer = SummaryWriter("./log/"+casename) #tensorboard

print(net)
writer.add_graph(net, images)
writer.close()
# Out:
# ModResv2(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (sigmoid): Sigmoid()
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=128, out_features=2048, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=128, out_features=2048, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=128, out_features=2048, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (self_attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=2048, out_features=2048, bias=True)
#   )
#   (seblock1): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=256, out_features=16, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=16, out_features=256, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (seblock2): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=32, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=32, out_features=512, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (seblock3): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=64, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=64, out_features=1024, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (seblock4): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=128, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=128, out_features=2048, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (fusion4): MultiScaleFusion(
#     (conv1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1))
#     (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(2048, 2048, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (fusion_conv): Conv2d(8192, 2048, kernel_size=(1, 1), stride=(1, 1))
#     (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (fusion1): MultiScaleFusion(
#     (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (fusion_conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (fc2): Linear(in_features=1024, out_features=24, bias=True)
#   (fc): Linear(in_features=2048, out_features=24, bias=True)
# )

# %% [markdown]
# # EXCUETE MODEL

# %%
if __name__ == "__main__":
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    torch.cuda.empty_cache()
    # Let's build our model
    train(200,device,net)
    print('Finished Training')

    #Epochごとのlossの保存
    #torch.save(net, "./result/"+casename+"/"+casename+".pt")
    # 保存网络中的参数, 速度快，占空间少
    #torch.save(net.state_dict(),'case-1-p.pt')
    #--------------------------------------------------
    #针对上面一般的保存方法，加载的方法分别是：
    # model_dict=torch.load(PATH)
    # model_dict=model.load_state_dict(torch.load(PATH))
    # Test which classes performed well
    valid(net, device, valid_loader, classes)
    # Let's load the model we just created and test the accuracy per label
    # model = net()
    # path = "myFirstModel.pth"
    # model.load_state_dict(torch.load(path))
# Out:
# [Epoch: 1/200] - Step: 10/1194 | Loss: 316.657 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 20/1194 | Loss: 315.314 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 30/1194 | Loss: 321.910 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 40/1194 | Loss: 321.615 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 50/1194 | Loss: 317.821 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 60/1194 | Loss: 322.328 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 70/1194 | Loss: 316.142 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 80/1194 | Loss: 319.715 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 90/1194 | Loss: 317.386 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 100/1194 | Loss: 322.442 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 110/1194 | Loss: 314.651 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 120/1194 | Loss: 322.668 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 130/1194 | Loss: 315.317 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 140/1194 | Loss: 313.139 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 150/1194 | Loss: 322.113 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 160/1194 | Loss: 311.615 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 170/1194 | Loss: 316.986 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 180/1194 | Loss: 322.141 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 190/1194 | Loss: 315.110 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 200/1194 | Loss: 323.193 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 210/1194 | Loss: 321.126 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 220/1194 | Loss: 325.664 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 230/1194 | Loss: 314.967 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 240/1194 | Loss: 320.304 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 250/1194 | Loss: 322.427 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 260/1194 | Loss: 315.662 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 270/1194 | Loss: 316.830 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 280/1194 | Loss: 316.745 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 290/1194 | Loss: 320.052 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 300/1194 | Loss: 321.978 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 310/1194 | Loss: 316.153 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 320/1194 | Loss: 317.129 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 330/1194 | Loss: 327.597 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 340/1194 | Loss: 320.342 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 350/1194 | Loss: 319.757 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 360/1194 | Loss: 317.268 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 370/1194 | Loss: 320.343 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 380/1194 | Loss: 314.355 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 390/1194 | Loss: 322.284 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 400/1194 | Loss: 319.620 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 410/1194 | Loss: 318.245 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 420/1194 | Loss: 322.303 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 430/1194 | Loss: 325.842 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 440/1194 | Loss: 323.019 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 450/1194 | Loss: 316.994 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 460/1194 | Loss: 320.461 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 470/1194 | Loss: 316.979 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 480/1194 | Loss: 315.709 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 490/1194 | Loss: 312.140 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 500/1194 | Loss: 316.057 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 510/1194 | Loss: 314.661 | Accuracy: 0.300
# [Epoch: 1/200] - Step: 520/1194 | Loss: 318.390 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 530/1194 | Loss: 322.247 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 540/1194 | Loss: 319.725 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 550/1194 | Loss: 316.961 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 560/1194 | Loss: 315.134 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 570/1194 | Loss: 327.696 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 580/1194 | Loss: 325.536 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 590/1194 | Loss: 321.648 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 600/1194 | Loss: 317.581 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 610/1194 | Loss: 321.040 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 620/1194 | Loss: 317.984 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 630/1194 | Loss: 318.626 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 640/1194 | Loss: 320.273 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 650/1194 | Loss: 316.606 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 660/1194 | Loss: 316.273 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 670/1194 | Loss: 320.021 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 680/1194 | Loss: 323.934 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 690/1194 | Loss: 326.000 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 700/1194 | Loss: 320.744 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 710/1194 | Loss: 317.157 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 720/1194 | Loss: 320.137 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 730/1194 | Loss: 318.993 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 740/1194 | Loss: 316.783 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 750/1194 | Loss: 314.550 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 760/1194 | Loss: 318.602 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 770/1194 | Loss: 319.978 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 780/1194 | Loss: 318.356 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 790/1194 | Loss: 318.261 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 800/1194 | Loss: 322.904 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 810/1194 | Loss: 318.966 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 820/1194 | Loss: 315.918 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 830/1194 | Loss: 321.449 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 840/1194 | Loss: 321.574 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 850/1194 | Loss: 317.120 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 860/1194 | Loss: 316.395 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 870/1194 | Loss: 324.145 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 880/1194 | Loss: 320.195 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 890/1194 | Loss: 320.124 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 900/1194 | Loss: 325.435 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 910/1194 | Loss: 316.110 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 920/1194 | Loss: 321.947 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 930/1194 | Loss: 324.393 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 940/1194 | Loss: 314.532 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 950/1194 | Loss: 318.957 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 960/1194 | Loss: 323.790 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 970/1194 | Loss: 320.588 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 980/1194 | Loss: 314.305 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 990/1194 | Loss: 312.180 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1000/1194 | Loss: 315.746 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1010/1194 | Loss: 311.580 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 1020/1194 | Loss: 315.938 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1030/1194 | Loss: 320.002 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1040/1194 | Loss: 314.028 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1050/1194 | Loss: 317.747 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1060/1194 | Loss: 311.159 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1070/1194 | Loss: 319.348 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1080/1194 | Loss: 317.923 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1090/1194 | Loss: 321.581 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1100/1194 | Loss: 314.107 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1110/1194 | Loss: 322.846 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1120/1194 | Loss: 320.769 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1130/1194 | Loss: 311.586 | Accuracy: 0.200
# [Epoch: 1/200] - Step: 1140/1194 | Loss: 315.857 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1150/1194 | Loss: 316.093 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1160/1194 | Loss: 319.850 | Accuracy: 0.000
# [Epoch: 1/200] - Step: 1170/1194 | Loss: 310.245 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1180/1194 | Loss: 317.368 | Accuracy: 0.100
# [Epoch: 1/200] - Step: 1190/1194 | Loss: 322.847 | Accuracy: 0.000
# Accuracy:  0.04918032786885246
# Model saved!
# [Epoch: 2/200] - Step: 10/1194 | Loss: 317.901 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 20/1194 | Loss: 317.767 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 30/1194 | Loss: 317.087 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 40/1194 | Loss: 314.705 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 50/1194 | Loss: 316.277 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 60/1194 | Loss: 317.432 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 70/1194 | Loss: 317.278 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 80/1194 | Loss: 313.900 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 90/1194 | Loss: 314.755 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 100/1194 | Loss: 317.604 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 110/1194 | Loss: 316.132 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 120/1194 | Loss: 319.182 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 130/1194 | Loss: 312.568 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 140/1194 | Loss: 311.575 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 150/1194 | Loss: 312.921 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 160/1194 | Loss: 311.310 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 170/1194 | Loss: 312.955 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 180/1194 | Loss: 318.572 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 190/1194 | Loss: 314.285 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 200/1194 | Loss: 322.818 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 210/1194 | Loss: 315.111 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 220/1194 | Loss: 318.105 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 230/1194 | Loss: 319.101 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 240/1194 | Loss: 313.669 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 250/1194 | Loss: 315.782 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 260/1194 | Loss: 316.444 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 270/1194 | Loss: 312.605 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 280/1194 | Loss: 308.036 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 290/1194 | Loss: 318.961 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 300/1194 | Loss: 316.661 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 310/1194 | Loss: 313.902 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 320/1194 | Loss: 318.226 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 330/1194 | Loss: 314.841 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 340/1194 | Loss: 314.636 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 350/1194 | Loss: 313.401 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 360/1194 | Loss: 316.915 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 370/1194 | Loss: 312.856 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 380/1194 | Loss: 315.689 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 390/1194 | Loss: 313.830 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 400/1194 | Loss: 310.136 | Accuracy: 0.400
# [Epoch: 2/200] - Step: 410/1194 | Loss: 317.433 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 420/1194 | Loss: 311.280 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 430/1194 | Loss: 312.489 | Accuracy: 0.300
# [Epoch: 2/200] - Step: 440/1194 | Loss: 315.418 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 450/1194 | Loss: 315.965 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 460/1194 | Loss: 317.172 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 470/1194 | Loss: 316.853 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 480/1194 | Loss: 311.425 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 490/1194 | Loss: 310.838 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 500/1194 | Loss: 315.237 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 510/1194 | Loss: 316.887 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 520/1194 | Loss: 309.765 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 530/1194 | Loss: 310.622 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 540/1194 | Loss: 322.778 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 550/1194 | Loss: 308.236 | Accuracy: 0.300
# [Epoch: 2/200] - Step: 560/1194 | Loss: 315.415 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 570/1194 | Loss: 314.530 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 580/1194 | Loss: 311.081 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 590/1194 | Loss: 315.861 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 600/1194 | Loss: 309.077 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 610/1194 | Loss: 312.806 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 620/1194 | Loss: 312.399 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 630/1194 | Loss: 313.943 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 640/1194 | Loss: 320.676 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 650/1194 | Loss: 315.956 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 660/1194 | Loss: 311.566 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 670/1194 | Loss: 312.634 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 680/1194 | Loss: 317.876 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 690/1194 | Loss: 315.526 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 700/1194 | Loss: 314.393 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 710/1194 | Loss: 310.462 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 720/1194 | Loss: 312.401 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 730/1194 | Loss: 319.229 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 740/1194 | Loss: 309.905 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 750/1194 | Loss: 315.394 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 760/1194 | Loss: 321.458 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 770/1194 | Loss: 310.998 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 780/1194 | Loss: 312.764 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 790/1194 | Loss: 311.076 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 800/1194 | Loss: 314.492 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 810/1194 | Loss: 308.886 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 820/1194 | Loss: 310.228 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 830/1194 | Loss: 305.916 | Accuracy: 0.400
# [Epoch: 2/200] - Step: 840/1194 | Loss: 315.357 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 850/1194 | Loss: 312.081 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 860/1194 | Loss: 312.651 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 870/1194 | Loss: 315.285 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 880/1194 | Loss: 315.532 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 890/1194 | Loss: 315.231 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 900/1194 | Loss: 313.063 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 910/1194 | Loss: 306.419 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 920/1194 | Loss: 316.887 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 930/1194 | Loss: 309.025 | Accuracy: 0.300
# [Epoch: 2/200] - Step: 940/1194 | Loss: 316.479 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 950/1194 | Loss: 312.204 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 960/1194 | Loss: 312.415 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 970/1194 | Loss: 307.203 | Accuracy: 0.300
# [Epoch: 2/200] - Step: 980/1194 | Loss: 317.802 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 990/1194 | Loss: 314.341 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 1000/1194 | Loss: 313.625 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1010/1194 | Loss: 307.939 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 1020/1194 | Loss: 312.447 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 1030/1194 | Loss: 311.175 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 1040/1194 | Loss: 307.890 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 1050/1194 | Loss: 316.706 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1060/1194 | Loss: 308.089 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 1070/1194 | Loss: 309.810 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 1080/1194 | Loss: 318.591 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1090/1194 | Loss: 313.201 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 1100/1194 | Loss: 315.745 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1110/1194 | Loss: 317.040 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1120/1194 | Loss: 312.326 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 1130/1194 | Loss: 315.390 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1140/1194 | Loss: 304.931 | Accuracy: 0.300
# [Epoch: 2/200] - Step: 1150/1194 | Loss: 318.601 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1160/1194 | Loss: 313.868 | Accuracy: 0.100
# [Epoch: 2/200] - Step: 1170/1194 | Loss: 309.422 | Accuracy: 0.200
# [Epoch: 2/200] - Step: 1180/1194 | Loss: 311.219 | Accuracy: 0.000
# [Epoch: 2/200] - Step: 1190/1194 | Loss: 307.486 | Accuracy: 0.200
# Accuracy:  0.10491803278688525
# Model saved!
# [Epoch: 3/200] - Step: 10/1194 | Loss: 314.269 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 20/1194 | Loss: 310.804 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 30/1194 | Loss: 311.587 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 40/1194 | Loss: 315.482 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 50/1194 | Loss: 311.887 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 60/1194 | Loss: 304.745 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 70/1194 | Loss: 314.002 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 80/1194 | Loss: 309.223 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 90/1194 | Loss: 313.923 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 100/1194 | Loss: 308.184 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 110/1194 | Loss: 303.000 | Accuracy: 0.400
# [Epoch: 3/200] - Step: 120/1194 | Loss: 313.516 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 130/1194 | Loss: 303.651 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 140/1194 | Loss: 303.016 | Accuracy: 0.400
# [Epoch: 3/200] - Step: 150/1194 | Loss: 313.052 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 160/1194 | Loss: 306.529 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 170/1194 | Loss: 311.531 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 180/1194 | Loss: 304.738 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 190/1194 | Loss: 302.832 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 200/1194 | Loss: 307.340 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 210/1194 | Loss: 310.026 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 220/1194 | Loss: 313.739 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 230/1194 | Loss: 309.994 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 240/1194 | Loss: 308.986 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 250/1194 | Loss: 306.767 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 260/1194 | Loss: 307.850 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 270/1194 | Loss: 310.980 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 280/1194 | Loss: 317.447 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 290/1194 | Loss: 310.098 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 300/1194 | Loss: 317.966 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 310/1194 | Loss: 312.472 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 320/1194 | Loss: 311.877 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 330/1194 | Loss: 311.004 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 340/1194 | Loss: 316.374 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 350/1194 | Loss: 307.701 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 360/1194 | Loss: 297.401 | Accuracy: 0.400
# [Epoch: 3/200] - Step: 370/1194 | Loss: 318.956 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 380/1194 | Loss: 311.075 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 390/1194 | Loss: 308.225 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 400/1194 | Loss: 316.833 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 410/1194 | Loss: 310.519 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 420/1194 | Loss: 315.021 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 430/1194 | Loss: 303.974 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 440/1194 | Loss: 308.359 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 450/1194 | Loss: 305.614 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 460/1194 | Loss: 302.386 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 470/1194 | Loss: 312.576 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 480/1194 | Loss: 300.346 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 490/1194 | Loss: 303.970 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 500/1194 | Loss: 312.797 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 510/1194 | Loss: 300.163 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 520/1194 | Loss: 309.966 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 530/1194 | Loss: 309.840 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 540/1194 | Loss: 310.925 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 550/1194 | Loss: 311.621 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 560/1194 | Loss: 315.699 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 570/1194 | Loss: 313.481 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 580/1194 | Loss: 310.035 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 590/1194 | Loss: 309.199 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 600/1194 | Loss: 311.952 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 610/1194 | Loss: 317.995 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 620/1194 | Loss: 313.863 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 630/1194 | Loss: 299.710 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 640/1194 | Loss: 305.659 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 650/1194 | Loss: 307.427 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 660/1194 | Loss: 311.107 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 670/1194 | Loss: 313.693 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 680/1194 | Loss: 318.470 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 690/1194 | Loss: 314.218 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 700/1194 | Loss: 308.150 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 710/1194 | Loss: 319.300 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 720/1194 | Loss: 297.729 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 730/1194 | Loss: 305.299 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 740/1194 | Loss: 302.486 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 750/1194 | Loss: 298.952 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 760/1194 | Loss: 309.292 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 770/1194 | Loss: 318.384 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 780/1194 | Loss: 307.119 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 790/1194 | Loss: 306.418 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 800/1194 | Loss: 313.052 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 810/1194 | Loss: 314.666 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 820/1194 | Loss: 303.983 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 830/1194 | Loss: 317.481 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 840/1194 | Loss: 310.753 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 850/1194 | Loss: 319.179 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 860/1194 | Loss: 305.962 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 870/1194 | Loss: 313.965 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 880/1194 | Loss: 297.600 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 890/1194 | Loss: 310.361 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 900/1194 | Loss: 313.763 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 910/1194 | Loss: 310.220 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 920/1194 | Loss: 313.909 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 930/1194 | Loss: 296.662 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 940/1194 | Loss: 309.160 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 950/1194 | Loss: 299.810 | Accuracy: 0.300
# [Epoch: 3/200] - Step: 960/1194 | Loss: 318.799 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 970/1194 | Loss: 305.625 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 980/1194 | Loss: 313.833 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 990/1194 | Loss: 312.259 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1000/1194 | Loss: 313.104 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1010/1194 | Loss: 308.008 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 1020/1194 | Loss: 318.712 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1030/1194 | Loss: 312.820 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1040/1194 | Loss: 303.167 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 1050/1194 | Loss: 304.184 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 1060/1194 | Loss: 315.324 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1070/1194 | Loss: 315.339 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1080/1194 | Loss: 300.723 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 1090/1194 | Loss: 312.411 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 1100/1194 | Loss: 307.618 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1110/1194 | Loss: 308.663 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 1120/1194 | Loss: 300.684 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 1130/1194 | Loss: 305.358 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 1140/1194 | Loss: 311.121 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 1150/1194 | Loss: 305.229 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 1160/1194 | Loss: 311.533 | Accuracy: 0.100
# [Epoch: 3/200] - Step: 1170/1194 | Loss: 319.734 | Accuracy: 0.000
# [Epoch: 3/200] - Step: 1180/1194 | Loss: 304.799 | Accuracy: 0.200
# [Epoch: 3/200] - Step: 1190/1194 | Loss: 298.812 | Accuracy: 0.300
# Accuracy:  0.10491803278688525
# [Epoch: 4/200] - Step: 10/1194 | Loss: 304.253 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 20/1194 | Loss: 318.211 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 30/1194 | Loss: 306.707 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 40/1194 | Loss: 305.848 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 50/1194 | Loss: 320.974 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 60/1194 | Loss: 305.048 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 70/1194 | Loss: 300.320 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 80/1194 | Loss: 302.587 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 90/1194 | Loss: 302.831 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 100/1194 | Loss: 311.230 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 110/1194 | Loss: 303.184 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 120/1194 | Loss: 308.242 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 130/1194 | Loss: 305.686 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 140/1194 | Loss: 310.946 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 150/1194 | Loss: 312.241 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 160/1194 | Loss: 300.733 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 170/1194 | Loss: 316.655 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 180/1194 | Loss: 293.250 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 190/1194 | Loss: 299.315 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 200/1194 | Loss: 309.484 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 210/1194 | Loss: 307.388 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 220/1194 | Loss: 306.055 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 230/1194 | Loss: 308.354 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 240/1194 | Loss: 305.114 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 250/1194 | Loss: 311.943 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 260/1194 | Loss: 307.851 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 270/1194 | Loss: 300.492 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 280/1194 | Loss: 311.748 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 290/1194 | Loss: 292.849 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 300/1194 | Loss: 312.569 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 310/1194 | Loss: 305.735 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 320/1194 | Loss: 302.023 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 330/1194 | Loss: 299.527 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 340/1194 | Loss: 301.096 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 350/1194 | Loss: 319.994 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 360/1194 | Loss: 307.266 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 370/1194 | Loss: 310.939 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 380/1194 | Loss: 298.186 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 390/1194 | Loss: 313.581 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 400/1194 | Loss: 308.613 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 410/1194 | Loss: 307.906 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 420/1194 | Loss: 303.439 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 430/1194 | Loss: 318.298 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 440/1194 | Loss: 306.938 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 450/1194 | Loss: 308.263 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 460/1194 | Loss: 292.115 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 470/1194 | Loss: 311.380 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 480/1194 | Loss: 309.914 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 490/1194 | Loss: 296.680 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 500/1194 | Loss: 303.140 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 510/1194 | Loss: 300.096 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 520/1194 | Loss: 321.093 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 530/1194 | Loss: 310.840 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 540/1194 | Loss: 313.461 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 550/1194 | Loss: 311.830 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 560/1194 | Loss: 314.916 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 570/1194 | Loss: 312.920 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 580/1194 | Loss: 300.675 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 590/1194 | Loss: 311.098 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 600/1194 | Loss: 306.063 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 610/1194 | Loss: 304.275 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 620/1194 | Loss: 304.936 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 630/1194 | Loss: 314.632 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 640/1194 | Loss: 297.437 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 650/1194 | Loss: 308.571 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 660/1194 | Loss: 305.130 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 670/1194 | Loss: 310.760 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 680/1194 | Loss: 283.519 | Accuracy: 0.500
# [Epoch: 4/200] - Step: 690/1194 | Loss: 307.267 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 700/1194 | Loss: 320.665 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 710/1194 | Loss: 312.197 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 720/1194 | Loss: 308.882 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 730/1194 | Loss: 306.406 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 740/1194 | Loss: 305.521 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 750/1194 | Loss: 309.192 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 760/1194 | Loss: 304.318 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 770/1194 | Loss: 309.847 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 780/1194 | Loss: 302.660 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 790/1194 | Loss: 311.580 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 800/1194 | Loss: 308.445 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 810/1194 | Loss: 297.377 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 820/1194 | Loss: 283.511 | Accuracy: 0.500
# [Epoch: 4/200] - Step: 830/1194 | Loss: 302.455 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 840/1194 | Loss: 313.426 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 850/1194 | Loss: 307.625 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 860/1194 | Loss: 314.473 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 870/1194 | Loss: 307.770 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 880/1194 | Loss: 308.840 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 890/1194 | Loss: 309.919 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 900/1194 | Loss: 307.807 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 910/1194 | Loss: 303.952 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 920/1194 | Loss: 313.496 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 930/1194 | Loss: 286.885 | Accuracy: 0.400
# [Epoch: 4/200] - Step: 940/1194 | Loss: 296.158 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 950/1194 | Loss: 310.452 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 960/1194 | Loss: 308.390 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 970/1194 | Loss: 318.873 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 980/1194 | Loss: 316.680 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 990/1194 | Loss: 304.266 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 1000/1194 | Loss: 307.232 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1010/1194 | Loss: 309.761 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 1020/1194 | Loss: 316.490 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 1030/1194 | Loss: 306.086 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1040/1194 | Loss: 305.652 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1050/1194 | Loss: 307.502 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1060/1194 | Loss: 301.382 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1070/1194 | Loss: 302.186 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1080/1194 | Loss: 296.897 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1090/1194 | Loss: 297.189 | Accuracy: 0.300
# [Epoch: 4/200] - Step: 1100/1194 | Loss: 301.034 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 1110/1194 | Loss: 314.404 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 1120/1194 | Loss: 303.513 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1130/1194 | Loss: 321.392 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 1140/1194 | Loss: 311.603 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1150/1194 | Loss: 307.918 | Accuracy: 0.200
# [Epoch: 4/200] - Step: 1160/1194 | Loss: 304.402 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1170/1194 | Loss: 310.141 | Accuracy: 0.000
# [Epoch: 4/200] - Step: 1180/1194 | Loss: 298.053 | Accuracy: 0.100
# [Epoch: 4/200] - Step: 1190/1194 | Loss: 296.953 | Accuracy: 0.200
# Accuracy:  0.10491803278688525
# [Epoch: 5/200] - Step: 10/1194 | Loss: 315.345 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 20/1194 | Loss: 305.962 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 30/1194 | Loss: 288.204 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 40/1194 | Loss: 311.358 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 50/1194 | Loss: 300.219 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 60/1194 | Loss: 312.133 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 70/1194 | Loss: 296.662 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 80/1194 | Loss: 297.484 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 90/1194 | Loss: 312.510 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 100/1194 | Loss: 291.634 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 110/1194 | Loss: 299.949 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 120/1194 | Loss: 288.346 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 130/1194 | Loss: 305.281 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 140/1194 | Loss: 300.064 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 150/1194 | Loss: 296.304 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 160/1194 | Loss: 314.538 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 170/1194 | Loss: 288.596 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 180/1194 | Loss: 305.905 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 190/1194 | Loss: 318.175 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 200/1194 | Loss: 315.399 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 210/1194 | Loss: 298.661 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 220/1194 | Loss: 290.427 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 230/1194 | Loss: 311.572 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 240/1194 | Loss: 275.586 | Accuracy: 0.400
# [Epoch: 5/200] - Step: 250/1194 | Loss: 303.740 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 260/1194 | Loss: 293.482 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 270/1194 | Loss: 318.659 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 280/1194 | Loss: 315.640 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 290/1194 | Loss: 308.732 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 300/1194 | Loss: 312.737 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 310/1194 | Loss: 316.120 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 320/1194 | Loss: 286.477 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 330/1194 | Loss: 299.140 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 340/1194 | Loss: 297.032 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 350/1194 | Loss: 281.131 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 360/1194 | Loss: 296.489 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 370/1194 | Loss: 319.769 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 380/1194 | Loss: 309.508 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 390/1194 | Loss: 305.556 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 400/1194 | Loss: 316.973 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 410/1194 | Loss: 314.628 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 420/1194 | Loss: 312.763 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 430/1194 | Loss: 303.672 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 440/1194 | Loss: 312.268 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 450/1194 | Loss: 311.358 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 460/1194 | Loss: 302.092 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 470/1194 | Loss: 309.227 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 480/1194 | Loss: 301.026 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 490/1194 | Loss: 310.217 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 500/1194 | Loss: 311.108 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 510/1194 | Loss: 302.341 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 520/1194 | Loss: 304.226 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 530/1194 | Loss: 307.008 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 540/1194 | Loss: 297.709 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 550/1194 | Loss: 293.690 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 560/1194 | Loss: 302.413 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 570/1194 | Loss: 292.834 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 580/1194 | Loss: 298.119 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 590/1194 | Loss: 307.628 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 600/1194 | Loss: 312.058 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 610/1194 | Loss: 301.869 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 620/1194 | Loss: 324.990 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 630/1194 | Loss: 304.921 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 640/1194 | Loss: 311.455 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 650/1194 | Loss: 299.848 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 660/1194 | Loss: 318.023 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 670/1194 | Loss: 305.490 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 680/1194 | Loss: 310.494 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 690/1194 | Loss: 300.119 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 700/1194 | Loss: 299.348 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 710/1194 | Loss: 312.837 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 720/1194 | Loss: 310.780 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 730/1194 | Loss: 297.168 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 740/1194 | Loss: 330.379 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 750/1194 | Loss: 306.029 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 760/1194 | Loss: 318.432 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 770/1194 | Loss: 301.359 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 780/1194 | Loss: 306.158 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 790/1194 | Loss: 321.196 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 800/1194 | Loss: 303.727 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 810/1194 | Loss: 302.347 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 820/1194 | Loss: 312.704 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 830/1194 | Loss: 301.828 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 840/1194 | Loss: 291.436 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 850/1194 | Loss: 282.144 | Accuracy: 0.400
# [Epoch: 5/200] - Step: 860/1194 | Loss: 313.409 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 870/1194 | Loss: 315.819 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 880/1194 | Loss: 316.452 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 890/1194 | Loss: 293.868 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 900/1194 | Loss: 309.230 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 910/1194 | Loss: 293.557 | Accuracy: 0.400
# [Epoch: 5/200] - Step: 920/1194 | Loss: 301.025 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 930/1194 | Loss: 310.622 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 940/1194 | Loss: 297.029 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 950/1194 | Loss: 307.820 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 960/1194 | Loss: 305.752 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 970/1194 | Loss: 281.520 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 980/1194 | Loss: 298.020 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 990/1194 | Loss: 320.289 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 1000/1194 | Loss: 312.982 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1010/1194 | Loss: 319.589 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 1020/1194 | Loss: 305.746 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1030/1194 | Loss: 305.520 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1040/1194 | Loss: 323.581 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 1050/1194 | Loss: 308.178 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1060/1194 | Loss: 301.753 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1070/1194 | Loss: 294.364 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 1080/1194 | Loss: 317.174 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 1090/1194 | Loss: 309.253 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1100/1194 | Loss: 300.821 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 1110/1194 | Loss: 304.677 | Accuracy: 0.000
# [Epoch: 5/200] - Step: 1120/1194 | Loss: 281.582 | Accuracy: 0.200
# [Epoch: 5/200] - Step: 1130/1194 | Loss: 299.623 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1140/1194 | Loss: 306.211 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1150/1194 | Loss: 287.453 | Accuracy: 0.300
# [Epoch: 5/200] - Step: 1160/1194 | Loss: 312.541 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1170/1194 | Loss: 302.890 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1180/1194 | Loss: 297.260 | Accuracy: 0.100
# [Epoch: 5/200] - Step: 1190/1194 | Loss: 299.965 | Accuracy: 0.100
# Accuracy:  0.10491803278688525
# [Epoch: 6/200] - Step: 10/1194 | Loss: 306.249 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 20/1194 | Loss: 284.831 | Accuracy: 0.400
# [Epoch: 6/200] - Step: 30/1194 | Loss: 297.917 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 40/1194 | Loss: 307.143 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 50/1194 | Loss: 303.345 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 60/1194 | Loss: 304.431 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 70/1194 | Loss: 303.114 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 80/1194 | Loss: 311.579 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 90/1194 | Loss: 292.519 | Accuracy: 0.300
# [Epoch: 6/200] - Step: 100/1194 | Loss: 305.292 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 110/1194 | Loss: 292.239 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 120/1194 | Loss: 314.402 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 130/1194 | Loss: 303.723 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 140/1194 | Loss: 307.607 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 150/1194 | Loss: 300.286 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 160/1194 | Loss: 285.964 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 170/1194 | Loss: 295.194 | Accuracy: 0.300
# [Epoch: 6/200] - Step: 180/1194 | Loss: 305.223 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 190/1194 | Loss: 310.554 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 200/1194 | Loss: 299.601 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 210/1194 | Loss: 284.747 | Accuracy: 0.300
# [Epoch: 6/200] - Step: 220/1194 | Loss: 302.866 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 230/1194 | Loss: 305.809 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 240/1194 | Loss: 314.592 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 250/1194 | Loss: 309.532 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 260/1194 | Loss: 299.856 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 270/1194 | Loss: 284.999 | Accuracy: 0.300
# [Epoch: 6/200] - Step: 280/1194 | Loss: 303.120 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 290/1194 | Loss: 296.849 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 300/1194 | Loss: 300.621 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 310/1194 | Loss: 303.864 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 320/1194 | Loss: 301.340 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 330/1194 | Loss: 304.340 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 340/1194 | Loss: 305.110 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 350/1194 | Loss: 298.086 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 360/1194 | Loss: 294.514 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 370/1194 | Loss: 299.166 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 380/1194 | Loss: 300.069 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 390/1194 | Loss: 312.783 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 400/1194 | Loss: 292.043 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 410/1194 | Loss: 278.744 | Accuracy: 0.400
# [Epoch: 6/200] - Step: 420/1194 | Loss: 287.691 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 430/1194 | Loss: 297.565 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 440/1194 | Loss: 326.496 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 450/1194 | Loss: 304.339 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 460/1194 | Loss: 306.929 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 470/1194 | Loss: 308.473 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 480/1194 | Loss: 312.837 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 490/1194 | Loss: 314.891 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 500/1194 | Loss: 273.184 | Accuracy: 0.400
# [Epoch: 6/200] - Step: 510/1194 | Loss: 311.319 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 520/1194 | Loss: 313.922 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 530/1194 | Loss: 293.963 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 540/1194 | Loss: 315.448 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 550/1194 | Loss: 316.943 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 560/1194 | Loss: 303.445 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 570/1194 | Loss: 316.214 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 580/1194 | Loss: 309.175 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 590/1194 | Loss: 310.273 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 600/1194 | Loss: 311.530 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 610/1194 | Loss: 269.659 | Accuracy: 0.400
# [Epoch: 6/200] - Step: 620/1194 | Loss: 300.258 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 630/1194 | Loss: 310.631 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 640/1194 | Loss: 299.343 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 650/1194 | Loss: 302.088 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 660/1194 | Loss: 315.585 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 670/1194 | Loss: 296.762 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 680/1194 | Loss: 301.765 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 690/1194 | Loss: 301.893 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 700/1194 | Loss: 299.748 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 710/1194 | Loss: 319.434 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 720/1194 | Loss: 293.887 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 730/1194 | Loss: 315.109 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 740/1194 | Loss: 301.153 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 750/1194 | Loss: 321.711 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 760/1194 | Loss: 305.668 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 770/1194 | Loss: 305.063 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 780/1194 | Loss: 311.097 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 790/1194 | Loss: 296.082 | Accuracy: 0.300
# [Epoch: 6/200] - Step: 800/1194 | Loss: 314.574 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 810/1194 | Loss: 314.244 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 820/1194 | Loss: 313.978 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 830/1194 | Loss: 291.359 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 840/1194 | Loss: 302.031 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 850/1194 | Loss: 307.317 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 860/1194 | Loss: 298.141 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 870/1194 | Loss: 304.838 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 880/1194 | Loss: 306.294 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 890/1194 | Loss: 294.293 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 900/1194 | Loss: 320.392 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 910/1194 | Loss: 309.814 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 920/1194 | Loss: 308.710 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 930/1194 | Loss: 311.204 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 940/1194 | Loss: 310.077 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 950/1194 | Loss: 307.544 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 960/1194 | Loss: 303.302 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 970/1194 | Loss: 296.128 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 980/1194 | Loss: 273.530 | Accuracy: 0.400
# [Epoch: 6/200] - Step: 990/1194 | Loss: 293.731 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 1000/1194 | Loss: 312.683 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 1010/1194 | Loss: 297.300 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 1020/1194 | Loss: 315.353 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 1030/1194 | Loss: 303.918 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 1040/1194 | Loss: 320.234 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 1050/1194 | Loss: 303.236 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 1060/1194 | Loss: 282.570 | Accuracy: 0.300
# [Epoch: 6/200] - Step: 1070/1194 | Loss: 298.915 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 1080/1194 | Loss: 310.431 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 1090/1194 | Loss: 309.200 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 1100/1194 | Loss: 294.177 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 1110/1194 | Loss: 294.305 | Accuracy: 0.300
# [Epoch: 6/200] - Step: 1120/1194 | Loss: 309.333 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 1130/1194 | Loss: 298.809 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 1140/1194 | Loss: 308.584 | Accuracy: 0.100
# [Epoch: 6/200] - Step: 1150/1194 | Loss: 318.572 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 1160/1194 | Loss: 277.215 | Accuracy: 0.400
# [Epoch: 6/200] - Step: 1170/1194 | Loss: 317.456 | Accuracy: 0.000
# [Epoch: 6/200] - Step: 1180/1194 | Loss: 295.568 | Accuracy: 0.200
# [Epoch: 6/200] - Step: 1190/1194 | Loss: 309.294 | Accuracy: 0.100
# Accuracy:  0.10491803278688525
# [Epoch: 7/200] - Step: 10/1194 | Loss: 300.424 | Accuracy: 0.200
# [Epoch: 7/200] - Step: 20/1194 | Loss: 286.726 | Accuracy: 0.300
# [Epoch: 7/200] - Step: 30/1194 | Loss: 289.696 | Accuracy: 0.200
# [Epoch: 7/200] - Step: 40/1194 | Loss: 298.822 | Accuracy: 0.100
# [Epoch: 7/200] - Step: 50/1194 | Loss: 311.596 | Accuracy: 0.100
# [Epoch: 7/200] - Step: 60/1194 | Loss: 298.316 | Accuracy: 0.100
# [Epoch: 7/200] - Step: 70/1194 | Loss: 304.010 | Accuracy: 0.100
# [Epoch: 7/200] - Step: 80/1194 | Loss: 313.984 | Accuracy: 0.000
# [Epoch: 7/200] - Step: 90/1194 | Loss: 299.484 | Accuracy: 0.100
# ...
# [Epoch: 199/200] - Step: 740/1194 | Loss: 287.731 | Accuracy: 0.300
# [Epoch: 199/200] - Step: 750/1194 | Loss: 296.604 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 760/1194 | Loss: 309.260 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 770/1194 | Loss: 292.660 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 780/1194 | Loss: 284.198 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 790/1194 | Loss: 288.499 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 800/1194 | Loss: 284.656 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 810/1194 | Loss: 314.134 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 820/1194 | Loss: 302.402 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 830/1194 | Loss: 281.236 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 840/1194 | Loss: 300.082 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 850/1194 | Loss: 291.820 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 860/1194 | Loss: 294.310 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 870/1194 | Loss: 292.299 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 880/1194 | Loss: 297.066 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 890/1194 | Loss: 288.847 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 900/1194 | Loss: 288.031 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 910/1194 | Loss: 307.025 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 920/1194 | Loss: 302.696 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 930/1194 | Loss: 294.553 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 940/1194 | Loss: 297.962 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 950/1194 | Loss: 308.201 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 960/1194 | Loss: 284.344 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 970/1194 | Loss: 305.489 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 980/1194 | Loss: 306.700 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 990/1194 | Loss: 285.504 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 1000/1194 | Loss: 291.955 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 1010/1194 | Loss: 307.963 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 1020/1194 | Loss: 281.183 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 1030/1194 | Loss: 302.022 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 1040/1194 | Loss: 300.939 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 1050/1194 | Loss: 287.055 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 1060/1194 | Loss: 288.114 | Accuracy: 0.300
# [Epoch: 199/200] - Step: 1070/1194 | Loss: 301.859 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 1080/1194 | Loss: 296.511 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 1090/1194 | Loss: 297.043 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 1100/1194 | Loss: 292.059 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 1110/1194 | Loss: 294.293 | Accuracy: 0.100
# [Epoch: 199/200] - Step: 1120/1194 | Loss: 279.736 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 1130/1194 | Loss: 291.659 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 1140/1194 | Loss: 276.172 | Accuracy: 0.300
# [Epoch: 199/200] - Step: 1150/1194 | Loss: 309.357 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 1160/1194 | Loss: 277.911 | Accuracy: 0.300
# [Epoch: 199/200] - Step: 1170/1194 | Loss: 294.663 | Accuracy: 0.000
# [Epoch: 199/200] - Step: 1180/1194 | Loss: 284.601 | Accuracy: 0.200
# [Epoch: 199/200] - Step: 1190/1194 | Loss: 284.340 | Accuracy: 0.200
# Accuracy:  0.10491803278688525
# [Epoch: 200/200] - Step: 10/1194 | Loss: 291.455 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 20/1194 | Loss: 299.838 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 30/1194 | Loss: 298.713 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 40/1194 | Loss: 303.331 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 50/1194 | Loss: 294.505 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 60/1194 | Loss: 296.396 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 70/1194 | Loss: 296.828 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 80/1194 | Loss: 264.336 | Accuracy: 0.400
# [Epoch: 200/200] - Step: 90/1194 | Loss: 298.441 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 100/1194 | Loss: 296.487 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 110/1194 | Loss: 301.362 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 120/1194 | Loss: 295.220 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 130/1194 | Loss: 281.984 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 140/1194 | Loss: 288.823 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 150/1194 | Loss: 323.955 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 160/1194 | Loss: 296.009 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 170/1194 | Loss: 296.353 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 180/1194 | Loss: 283.545 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 190/1194 | Loss: 285.964 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 200/1194 | Loss: 304.625 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 210/1194 | Loss: 313.596 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 220/1194 | Loss: 279.202 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 230/1194 | Loss: 294.791 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 240/1194 | Loss: 286.813 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 250/1194 | Loss: 288.875 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 260/1194 | Loss: 286.594 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 270/1194 | Loss: 305.747 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 280/1194 | Loss: 299.901 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 290/1194 | Loss: 292.735 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 300/1194 | Loss: 298.418 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 310/1194 | Loss: 298.936 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 320/1194 | Loss: 287.517 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 330/1194 | Loss: 292.443 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 340/1194 | Loss: 278.182 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 350/1194 | Loss: 330.520 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 360/1194 | Loss: 333.185 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 370/1194 | Loss: 258.328 | Accuracy: 0.500
# [Epoch: 200/200] - Step: 380/1194 | Loss: 290.425 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 390/1194 | Loss: 277.590 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 400/1194 | Loss: 304.374 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 410/1194 | Loss: 298.408 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 420/1194 | Loss: 316.071 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 430/1194 | Loss: 294.402 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 440/1194 | Loss: 271.237 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 450/1194 | Loss: 278.705 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 460/1194 | Loss: 288.599 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 470/1194 | Loss: 283.044 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 480/1194 | Loss: 293.238 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 490/1194 | Loss: 319.084 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 500/1194 | Loss: 310.360 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 510/1194 | Loss: 297.529 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 520/1194 | Loss: 313.608 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 530/1194 | Loss: 303.731 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 540/1194 | Loss: 337.571 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 550/1194 | Loss: 289.536 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 560/1194 | Loss: 279.070 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 570/1194 | Loss: 301.978 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 580/1194 | Loss: 298.481 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 590/1194 | Loss: 305.682 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 600/1194 | Loss: 298.077 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 610/1194 | Loss: 298.502 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 620/1194 | Loss: 294.800 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 630/1194 | Loss: 288.746 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 640/1194 | Loss: 285.995 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 650/1194 | Loss: 297.485 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 660/1194 | Loss: 290.498 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 670/1194 | Loss: 294.869 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 680/1194 | Loss: 290.012 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 690/1194 | Loss: 298.691 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 700/1194 | Loss: 306.482 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 710/1194 | Loss: 297.200 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 720/1194 | Loss: 293.889 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 730/1194 | Loss: 281.371 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 740/1194 | Loss: 290.035 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 750/1194 | Loss: 297.092 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 760/1194 | Loss: 292.541 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 770/1194 | Loss: 291.403 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 780/1194 | Loss: 329.952 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 790/1194 | Loss: 297.655 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 800/1194 | Loss: 304.941 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 810/1194 | Loss: 298.063 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 820/1194 | Loss: 294.216 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 830/1194 | Loss: 307.471 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 840/1194 | Loss: 289.281 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 850/1194 | Loss: 299.741 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 860/1194 | Loss: 283.893 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 870/1194 | Loss: 281.534 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 880/1194 | Loss: 294.182 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 890/1194 | Loss: 303.317 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 900/1194 | Loss: 293.185 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 910/1194 | Loss: 278.222 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 920/1194 | Loss: 272.610 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 930/1194 | Loss: 295.148 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 940/1194 | Loss: 297.152 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 950/1194 | Loss: 307.787 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 960/1194 | Loss: 283.318 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 970/1194 | Loss: 267.084 | Accuracy: 0.400
# [Epoch: 200/200] - Step: 980/1194 | Loss: 297.767 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 990/1194 | Loss: 287.377 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1000/1194 | Loss: 296.111 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1010/1194 | Loss: 299.850 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1020/1194 | Loss: 276.540 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 1030/1194 | Loss: 291.990 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 1040/1194 | Loss: 312.564 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 1050/1194 | Loss: 283.994 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 1060/1194 | Loss: 298.296 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1070/1194 | Loss: 294.633 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1080/1194 | Loss: 295.875 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 1090/1194 | Loss: 293.371 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1100/1194 | Loss: 302.030 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 1110/1194 | Loss: 293.320 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 1120/1194 | Loss: 304.319 | Accuracy: 0.000
# [Epoch: 200/200] - Step: 1130/1194 | Loss: 283.652 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 1140/1194 | Loss: 289.634 | Accuracy: 0.200
# [Epoch: 200/200] - Step: 1150/1194 | Loss: 272.444 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 1160/1194 | Loss: 302.881 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1170/1194 | Loss: 288.771 | Accuracy: 0.100
# [Epoch: 200/200] - Step: 1180/1194 | Loss: 273.039 | Accuracy: 0.300
# [Epoch: 200/200] - Step: 1190/1194 | Loss: 291.787 | Accuracy: 0.000
# Accuracy:  0.10491803278688525
# Training completed in:  44.138338786665834  hours
# Finished Training
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/br-python/anaconda3/envs/pytorch/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.1049
# Precision: 0.0110
# Recall: 0.1049
# F1 Score: 0.0199
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         0-10       0.00      0.00      0.00         0
#        10-20       0.00      0.00      0.00         0
#        20-30       0.00      0.00      0.00         0
#        30-40       0.00      0.00      0.00         4
#        40-50       0.00      0.00      0.00        22
#        50-60       0.00      0.00      0.00        13
#        60-70       0.00      0.00      0.00        12
#        70-80       0.00      0.00      0.00        20
#        80-90       0.00      0.00      0.00        14
#       90-100       0.00      0.00      0.00         8
#      100-110       0.00      0.00      0.00        17
#      110-120       0.00      0.00      0.00        11
#      120-130       0.00      0.00      0.00        10
#      130-140       0.00      0.00      0.00         9
#      140-150       0.00      0.00      0.00        10
#      150-160       0.00      0.00      0.00        16
#      160-170       0.00      0.00      0.00        15
#      170-180       0.00      0.00      0.00        10
#      180-190       0.00      0.00      0.00        15
#      190-200       0.00      0.00      0.00        15
#      200-210       0.00      0.00      0.00        21
#      210-220       0.00      0.00      0.00        22
#      220-230       0.10      1.00      0.19        32
#      230-240       0.00      0.00      0.00         9
#
#    micro avg       0.10      0.10      0.10       305
#    macro avg       0.00      0.04      0.01       305
# weighted avg       0.01      0.10      0.02       305

# %%
import time
net.to(device)
net.eval()
predictions = []
label1 = []
dataiter=iter(valid_loader)
images, label0 = dataiter.__next__()

start_time = time.process_time()
with torch.no_grad():
        images = images.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        predictions.extend(predicted.cpu().numpy())
end_time = time.process_time()

print("Prediction completed in: ", (end_time - start_time), " seconds")

print(predictions, label0)
# Out:
# Prediction completed in:  0.3873730990162585  seconds
# [22] tensor([13])
