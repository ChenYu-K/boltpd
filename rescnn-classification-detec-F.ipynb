# %%
import numpy
import pandas as pd
import torch
import numpy as np
#from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import TensorDataset, DataLoader
import os,random
import torchvision.transforms as T
import csv
import cv2
from torch.utils.data import Dataset
from torchvision import transforms
import torch.nn.functional as F
from PIL import Image
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.autograd import Variable
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import seaborn as sns
from scipy.fft import fft2, ifft2, fftshift
#my imports

import train

from torch.utils.tensorboard import SummaryWriter #tensorboard --logdir log --bind_all

# %%
current_directory = os.getcwd()
print("当前路径:", current_directory)

import torch

print(torch.__version__)
print(torch.cuda.is_available())

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# x = torch.tensor([1, 2, 3]).to(device)
# print(x.device)
# Out:
# 当前路径: /home/br-python/Documents/chen/boltpd
# 2.0.0+cu117
# True

# %%
def classify_force(force):
        # 将轴力分为10个单位一类的标签，并确保标签在0-23之间
        return min(int(force // 10), 23)

label=classify_force(125)
print(label)
# Out:
# 12

# %%
import os
import random
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from PIL import Image
import cv2

# Custom transform for adding Gaussian noise
class AddGaussianNoise(object):
    def __init__(self, mean=0.0, std=1.0):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        noise = torch.randn(tensor.size()) * self.std + self.mean
        return tensor + noise

    def __repr__(self):
        return f'{self.__class__.__name__}(mean={self.mean}, std={self.std})'

# Data augmentation transform
augment_transform = transforms.Compose([
    #transforms.Resize(1200),
    #transforms.RandomHorizontalFlip(),
    #transforms.RandomVerticalFlip(),
    #transforms.RandomRotation(20),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    AddGaussianNoise(mean=0.0, std=0.1),
    transforms.Normalize((0.5,), (0.5,))
])

# Original transform
original_transform = transforms.Compose([
    #transforms.Resize(1200),
    #transforms.CenterCrop(800),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

def generate_augmented_dataset(dir, csv_file, augment_times=5):
    pathDir = os.listdir(dir)
    filenumber = len(pathDir)
    sample = random.sample(pathDir, filenumber)
    
    file = pd.read_csv(csv_file)
    file = np.array(file)
    labels = []
    img_data = []

    def classify_force(force):
        return min((force // 10), 23)

    for file_name in sample:
        if file_name != "Thumbs.db":
            if int(file_name[-9:-4]) > 2097 and int(file_name[-9:-4]) < 3597:
                img_dir = os.path.join(dir, file_name)
                img = cv2.imread(img_dir, cv2.IMREAD_GRAYSCALE)
                ref_img = cv2.imread('database/202404-inkan/output-resize/DSC02098.JPG', cv2.IMREAD_GRAYSCALE)
                img_diff = cv2.absdiff(img, ref_img)
                crop_img = img[300:700, 450:850]

                pimg = Image.fromarray(crop_img)

                for _ in range(augment_times):
                    augmented_img = augment_transform(pimg)
                    img_data.append(augmented_img)

                original_img = original_transform(pimg)
                img_data.append(original_img)

                for item in file:
                    sh = item[1]
                    if file_name[-9:-4] == sh[-9:-4]:
                        force = item[0]
                        label = classify_force(force)
                        labels.extend([label] * (augment_times + 1))
    
    labels = torch.tensor(labels, dtype=torch.long)
    return img_data, labels

class MyDataset(Dataset):
    def __init__(self, data, labels, transform=None, target_transform=None):
        self.transform = transform
        self.target_transform = target_transform
        self.imgs = list(zip(data, labels))

    def __getitem__(self, index):
        fn, label = self.imgs[index]
        return fn, label

    def __len__(self):
        return len(self.imgs)

traindir = 'database/202404-inkan/output-resize/'
validdir = 'database/202404-inkan/valid-or/'
csv_file = './label/AI-bolt-color-202404-inkan.csv'

train_rdata, train_label = generate_augmented_dataset(traindir, csv_file, augment_times=4)
valid_rdata, valid_label = generate_augmented_dataset(validdir, csv_file, augment_times=4)

train_data = MyDataset(train_rdata, train_label)
valid_data = MyDataset(valid_rdata, valid_label)

train_loader = DataLoader(dataset=train_data, batch_size=1, shuffle=True)
valid_loader = DataLoader(dataset=valid_data, batch_size=1, shuffle=True)

# %%
print(len(train_rdata), len(train_label))
print(len(valid_rdata), len(valid_label))
dataiter=iter(train_loader)
images, labels = dataiter.__next__()
print(images.shape)
print(labels)
print(labels.shape)
topic = T.ToPILImage()
imm1 = topic(images[0])
vimg, vlabels = dataiter.__next__()
plt.imshow(topic(vimg[0]))
# Out:
# 5970 5970
# 1525 1525
# torch.Size([2, 1, 400, 400])
# tensor([ 4, 21])
# torch.Size([2])

# %% [markdown]
# # defin model

# %%
class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid())

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y
    
class Bottleneck(nn.Module):
    """
    __init__
        in_channel：残差块输入通道数
        out_channel：残差块输出通道数
        stride：卷积步长
        downsample：在_make_layer函数中赋值，用于控制shortcut图片下采样 H/2 W/2
    """
    expansion = 4   # 残差块第3个卷积层的通道膨胀倍率
    def __init__(self, in_channel, out_channel, stride=1, downsample=None):
        super(Bottleneck, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=in_channel, out_channels=out_channel, kernel_size=1, stride=1, bias=False)   # H,W不变。C: in_channel -> out_channel
        self.bn1 = nn.BatchNorm2d(num_features=out_channel)
        self.conv2 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel, kernel_size=3, stride=stride, bias=False, padding=1)  # H/2，W/2。C不变
        self.bn2 = nn.BatchNorm2d(num_features=out_channel)
        self.conv3 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel*self.expansion, kernel_size=1, stride=1, bias=False)   # H,W不变。C: out_channel -> 4*out_channel
        self.bn3 = nn.BatchNorm2d(num_features=out_channel*self.expansion)
        self.relu = nn.ReLU(inplace=True)
        # Add SEBlock
        self.seblock = SEBlock(out_channel*self.expansion)
        self.downsample = downsample
    
    def forward(self, x):
        identity = x    # 将原始输入暂存为shortcut的输出
        if self.downsample is not None:
            identity = self.downsample(x)   # 如果需要下采样，那么shortcut后:H/2，W/2。C: out_channel -> 4*out_channel(见ResNet中的downsample实现)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)

        out = self.conv3(out)
        out = self.bn3(out)

        #Apply SEBlock
        out = self.seblock(out)

        out += identity     # 残差连接0 n
        out = self.relu(out)

        return out


class ModResdic(nn.Module):
    """
    __init__
        block: 堆叠的基本模块
        block_num: 基本模块堆叠个数,是一个list,对于resnet50=[3,4,6,3]
        num_classes: 全连接之后的分类特征维度

    _make_layer
        block: 堆叠的基本模块
        channel: 每个stage中堆叠模块的第一个卷积的卷积核个数，对resnet50分别是:64,128,256,512
        block_num: 当期stage堆叠block个数
        stride: 默认卷积步长
    """
    def __init__(self, block, block_num, num_classes, num_attention_heads=4):
        super(ModResdic, self).__init__()
        self.in_channel = 64    # conv1的输出维度
        self.conv1 = nn.Conv2d(in_channels=2, out_channels=self.in_channel, kernel_size=7, stride=2, padding=3, bias=False)     # H/2,W/2。C:3->64
        self.bn1 = nn.BatchNorm2d(self.in_channel)
        self.relu = nn.ReLU(inplace=True)
        self.activation = nn.LeakyReLU(negative_slope=0.01)
        self.sigmoid = nn.Sigmoid()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)     # H/2,W/2。C不变
        self.layer1 = self._make_layer(block=block, channel=64, block_num=block_num[0], stride=1)   # H,W不变。downsample控制的shortcut，out_channel=64x4=256
        self.layer2 = self._make_layer(block=block, channel=128, block_num=block_num[1], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=128x4=512
        self.layer3 = self._make_layer(block=block, channel=256, block_num=block_num[2], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=256x4=1024
        self.layer4 = self._make_layer(block=block, channel=512, block_num=block_num[3], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=512x4=2048

        # 添加自注意力层
        self.self_attention = nn.MultiheadAttention(embed_dim=2048, num_heads=num_attention_heads)

        # Add SEBlocks after each residual block in the feature extraction layers
        self.seblock1 = SEBlock(64 * block.expansion)
        self.seblock2 = SEBlock(128 * block.expansion)
        self.seblock3 = SEBlock(256 * block.expansion)
        self.seblock4 = SEBlock(512 * block.expansion)

        self.fusion4 = MultiScaleFusion(1024 * block.expansion)
        self.fusion3 = MultiScaleFusion(512 * block.expansion)
        self.fusion2 = MultiScaleFusion(256 * block.expansion)
        self.fusion1 = MultiScaleFusion(128 * block.expansion)

        self.avgpool = nn.AdaptiveAvgPool2d((1,1))  # 将每张特征图大小->(1,1)，则经过池化后的输出维度=通道数
        self.fc1 = nn.Linear(in_features=512*block.expansion, out_features=1024) #in=2048,out=1024
        self.dropout = nn.Dropout(0.8) #dropout rate
        self.fc2 = nn.Linear(in_features=2048, out_features=1024) #in=1024, out=1
        self.fc3 = nn.Linear(in_features=1024, out_features=num_classes) #in=512, out=1
        #self.fc4 = nn.Linear(in_features=64, out_features=num_classes) #in=128, out=1

        self.fc = nn.Linear(512 * block.expansion, num_classes)

        # Upsampling layers for feature fusion
        self.upsample = lambda x: nn.functional.interpolate(x, scale_factor=2, mode='bilinear', align_corners=None).to(x.device)
        #self.upsample = nn.functional.interpolate(scale_factor=2, mode='bilinear', align_corners=True)
        
        for m in self.modules():    # 权重初始化
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

    def _make_layer(self, block, channel, block_num, stride=1):
        downsample = None   # 用于控制shorcut路的
        if stride != 1 or self.in_channel != channel*block.expansion:   # 对resnet50：conv2中特征图尺寸H,W不需要下采样/2，但是通道数x4，因此shortcut通道数也需要x4。对其余conv3,4,5，既要特征图尺寸H,W/2，又要shortcut维度x4
            downsample = nn.Sequential(
                nn.Conv2d(in_channels=self.in_channel, out_channels=channel*block.expansion, kernel_size=1, stride=stride, bias=False), # out_channels决定输出通道数x4，stride决定特征图尺寸H,W/2
                nn.BatchNorm2d(num_features=channel*block.expansion))

        layers = []  # 每一个convi_x的结构保存在一个layers列表中，i={2,3,4,5}
        layers.append(block(in_channel=self.in_channel, out_channel=channel, downsample=downsample, stride=stride)) # 定义convi_x中的第一个残差块，只有第一个需要设置downsample和stride
        self.in_channel = channel*block.expansion   # 在下一次调用_make_layer函数的时候，self.in_channel已经x4

        for _ in range(1, block_num):  # 通过循环堆叠其余残差块(堆叠了剩余的block_num-1个)
            layers.append(block(in_channel=self.in_channel, out_channel=channel))

        return nn.Sequential(*layers)   # '*'的作用是将list转换为非关键字参数传入

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.activation(x)
        x = self.maxpool(x)

        x1 = self.layer1(x)
        x1 = self.fusion1(x1)
        x1 = self.seblock1(x1)
        x2 = self.layer2(x1)
        #x2 = self.seblock2(x2)
        #x2 = self.fusion2(x2)
        x3 = self.layer3(x2)
        #x3 = self.seblock3(x3)
        #x3 = self.fusion3(x3)
        x4 = self.layer4(x3)
        x4 = self.seblock4(x4)
        x4 = self.fusion4(x4)

        x = self.avgpool(x4)
        x = torch.flatten(x, 1)

        # 添加自注意力层
        x, _ = self.self_attention(x.unsqueeze(0), x.unsqueeze(0), x.unsqueeze(0))
        x = x.squeeze(0)  # 移除添加的维度以适应全连接层的输入要求

        #x = x.unsqueeze(0)  # 添加一个维度以适应自注意力层的输入要求
        #x, _ = self.self_attention(x, x, x)
        
        #x = self.relu(self.fc1(x))
        #x = self.relu(self.fc2(x))
        #x = self.dropout(x)
        x = self.fc3(x)

        return x

class MultiScaleFusion(nn.Module):
    def __init__(self,out_channels):
        super(MultiScaleFusion, self).__init__()
        self.conv1 = nn.Conv2d(out_channels, out_channels, kernel_size=1, stride=1, padding=0)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(out_channels, out_channels, kernel_size=5, stride=1, padding=2)
        # 定义融合的卷积层
        self.fusion_conv = nn.Conv2d(4*out_channels, out_channels, kernel_size=1)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x1 = self.conv1(x)
        x2 = self.conv2(x)
        x3 = self.conv3(x)
        out = torch.cat([x,x1, x2, x3], dim=1)
        # 对融合的特征图进行卷积操作
        out = self.fusion_conv(out)
        out = self.bn(out)
        out = self.relu(out)
        return out
    
class ModResv2(nn.Module):
    """
    __init__
        block: 堆叠的基本模块
        block_num: 基本模块堆叠个数,是一个list,对于resnet50=[3,4,6,3]
        num_classes: 全连接之后的分类特征维度

    _make_layer
        block: 堆叠的基本模块
        channel: 每个stage中堆叠模块的第一个卷积的卷积核个数，对resnet50分别是:64,128,256,512
        block_num: 当期stage堆叠block个数
        stride: 默认卷积步长
    """
    def __init__(self, block, block_num, num_classes, num_attention_heads=4):
        super(ModResv2, self).__init__()
        self.in_channel = 64    # conv1的输出维度

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=self.in_channel, kernel_size=7, stride=2, padding=3, bias=False)     # H/2,W/2。C:3->64
        self.bn1 = nn.BatchNorm2d(self.in_channel)
        self.relu = nn.ReLU(inplace=True)
        self.activation = nn.LeakyReLU(negative_slope=0.01)
        self.sigmoid = nn.Sigmoid()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)     # H/2,W/2。C不变
        self.layer1 = self._make_layer(block=block, channel=64, block_num=block_num[0], stride=1)   # H,W不变。downsample控制的shortcut，out_channel=64x4=256
        self.layer2 = self._make_layer(block=block, channel=128, block_num=block_num[1], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=128x4=512
        self.layer3 = self._make_layer(block=block, channel=256, block_num=block_num[2], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=256x4=1024
        self.layer4 = self._make_layer(block=block, channel=512, block_num=block_num[3], stride=2)  # H/2, W/2。downsample控制的shortcut，out_channel=512x4=2048
        
        self.self_attention = nn.MultiheadAttention(embed_dim=2048, num_heads=num_attention_heads)

        # Add SEBlocks after each residual block in the feature extraction layers
        self.seblock1 = SEBlock(64 * block.expansion)
        self.seblock2 = SEBlock(128 * block.expansion)
        self.seblock3 = SEBlock(256 * block.expansion)
        self.seblock4 = SEBlock(512 * block.expansion)

        self.fusion4 = MultiScaleFusion(512 * block.expansion)
        #self.fusion3 = MultiScaleFusion(256 * block.expansion)
        #self.fusion2 = MultiScaleFusion(128 * block.expansion)
        self.fusion1 = MultiScaleFusion(64 * block.expansion)


        self.avgpool = nn.AdaptiveAvgPool2d((1,1))  # 将每张特征图大小->(1,1)，则经过池化后的输出维度=通道数
        self.fc1 = nn.Linear(in_features=512*block.expansion, out_features=1024) #in=2048,out=1024
        self.dropout = nn.Dropout(0.6) #dropout rate
        self.fc2 = nn.Linear(in_features=1024, out_features=num_classes) #in=1024, out=1
        #self.fc3 = nn.Linear(in_features=512, out_features=num_classes) #in=512, out=1
        #self.fc4 = nn.Linear(in_features=64, out_features=num_classes) #in=128, out=1
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        # Upsampling layers for feature fusion
        self.upsample = lambda x: nn.functional.interpolate(x, scale_factor=2, mode='bilinear', align_corners=None).to(x.device)
        #self.upsample = nn.functional.interpolate(scale_factor=2, mode='bilinear', align_corners=True)
        
        for m in self.modules():    # 权重初始化
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

    def _make_layer(self, block, channel, block_num, stride=1):
        downsample = None   # 用于控制shorcut路的
        if stride != 1 or self.in_channel != channel*block.expansion:   # 对resnet50：conv2中特征图尺寸H,W不需要下采样/2，但是通道数x4，因此shortcut通道数也需要x4。对其余conv3,4,5，既要特征图尺寸H,W/2，又要shortcut维度x4
            downsample = nn.Sequential(
                nn.Conv2d(in_channels=self.in_channel, out_channels=channel*block.expansion, kernel_size=1, stride=stride, bias=False), # out_channels决定输出通道数x4，stride决定特征图尺寸H,W/2
                nn.BatchNorm2d(num_features=channel*block.expansion))

        layers = []  # 每一个convi_x的结构保存在一个layers列表中，i={2,3,4,5}
        layers.append(block(in_channel=self.in_channel, out_channel=channel, downsample=downsample, stride=stride)) # 定义convi_x中的第一个残差块，只有第一个需要设置downsample和stride
        self.in_channel = channel*block.expansion   # 在下一次调用_make_layer函数的时候，self.in_channel已经x4

        for _ in range(1, block_num):  # 通过循环堆叠其余残差块(堆叠了剩余的block_num-1个)
            layers.append(block(in_channel=self.in_channel, out_channel=channel))

        return nn.Sequential(*layers)   # '*'的作用是将list转换为非关键字参数传入

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x1 = self.layer1(x)
        x1 = self.seblock1(x1)
        x1 = self.fusion1(x1)
        x2 = self.layer2(x1)
        x2 = self.seblock2(x2)
        x3 = self.layer3(x2)
        x3 = self.seblock3(x3)
        x4 = self.layer4(x3)
        x4 = self.seblock4(x4)
        x4 = self.fusion4(x4)

        x = self.avgpool(x4)
        x = torch.flatten(x, 1)

        # 添加自注意力层
        x, _ = self.self_attention(x.unsqueeze(0), x.unsqueeze(0), x.unsqueeze(0))
        x = x.squeeze(0) 

        #x = self.activation(self.fc1(x))
        x = self.dropout(x)
        #x = self.activation(self.fc2(x))
        x = self.fc(x)

        return x

# %%
def testAccuracy(net, epoch, device):
    net.eval()
    accuracy = 0.0
    total = 0.0
    with torch.no_grad():
        for i, (images, labels) in enumerate(valid_loader, 0):
            images = images.to(device)
            labels = labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            accuracy += (predicted == labels).sum().item()

    accuracy = accuracy / total
    print('Accuracy: ', accuracy)
    writer.add_scalar('Valid-ACC', accuracy, epoch + 1)
    return accuracy

def valid(model, device, valid_loader, classes):
    model.eval()
    all_labels = []
    all_predictions = []
    
    with torch.no_grad():
        for images, labels in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    # 计算各项指标
    accuracy = accuracy_score(all_labels, all_predictions)
    precision = precision_score(all_labels, all_predictions, average='weighted', labels=np.arange(24))
    recall = recall_score(all_labels, all_predictions, average='weighted', labels=np.arange(24))
    f1 = f1_score(all_labels, all_predictions, average='weighted', labels=np.arange(24))
    conf_matrix = confusion_matrix(all_labels, all_predictions, labels=np.arange(24))
    class_report = classification_report(all_labels, all_predictions, target_names=classes, labels=np.arange(24))

    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print('\nClassification Report:\n', class_report)

    # 绘制混淆矩阵
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

    return accuracy, precision, recall, f1, conf_matrix, class_report

def train(num_epochs,device,net):
    import time
    start_time = time.process_time()
    best_accuracy = 0.0

    k=0
    predata=[]
    labeldata=[]
    mseloss=[]
    trainnum=[]
    epochout=[]
    epochV=[]
    vloss=[]
    vr2=[]
    # Convert model parameters and buffers to CPU or Cuda
    net.to(device)
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        running_loss = 0.0
        running_corrects = 0.0
        total_samples = 0

        for i, (images, labels) in enumerate(train_loader, 0):
            images = Variable(images.to(device))
            labels = Variable(labels.to(device))
            optimizer.zero_grad()
            prediction = net(images)
            loss = loss_func(prediction, labels)*100
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            _, predicted = torch.max(prediction.data, 1)
            running_corrects += (predicted == labels).sum().item()
            total_samples += labels.size(0)
            
            if (i+1) % 10 == 0:
                avg_loss = running_loss / 10
                avg_acc = running_corrects / total_samples
                
                print(f'[Epoch: {epoch+1}/{num_epochs}] - Step: {i+1}/{len(train_loader)} | Loss: {avg_loss:.3f} | Accuracy: {avg_acc:.3f}')

                mseloss.append(running_loss/10)
                trainnum.append(i+1)
                epochout.append(epoch+1)
                result=pd.DataFrame({'epoch':epochout,'trainnum':trainnum,'loss':mseloss})
                result.to_csv("./result/"+casename+"/"+casename+"-result.csv",index=False,sep=',')

                # Tensorboard
                writer.add_scalar('Training loss', avg_loss, epoch * len(train_loader) + i)
                writer.add_scalar('ACC', avg_acc, epoch * len(train_loader) + i)

                # zero the loss
                running_loss = 0.0
                running_corrects = 0.0
                total_samples = 0

            predata.append(prediction.data.cpu().numpy()[0])
            labeldata.append(labels.data.cpu().numpy()[0])

        valid_accuracy = testAccuracy(net, epoch, device)
        if valid_accuracy > best_accuracy:
            best_accuracy = valid_accuracy
            torch.save(net.state_dict(), 'best_model_'+casename+'.pth')
            print('Model saved!')

    end_time = time.process_time()
    print("Training completed in: ", (end_time - start_time) / 3600, " hours")

def predict(net, device, dataloader):
    net.to(device)
    net.eval()
    predictions = []
    labels = []
    with torch.no_grad():
        for images, labels_batch in dataloader:
            images = images.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            predictions.extend(predicted.cpu().numpy())
            labels.extend(labels_batch.cpu().numpy())
    return predictions, labels

# %% [markdown]
# # 超参数Parameter

# %%
#from net import ResNet, Bottleneck
#from SEBlock import SEBlock
from loss_func import HuberLossPena

classes = [f'{i*10}-{i*10+10}' for i in range(24)]
    
# 输入输出的数据维度，这里都是1维
INPUT_FEATURE_DIM = 5000
# 隐含层中神经元的个数
#NEURON_NUM = 500
#OUTPUT_FEATURE_DIM = 1
# 学习率，越大学的越快，但也容易造成不稳定，准确率上下波动的情况
LEARNING_RATE = 2e-4

# 定义模型
net = ModResv2(block=Bottleneck, block_num=[3,4,6,3],num_classes=24) #152 (3,4,36,3)

# 训练网络
# 这里也可以使用其它的优化方法
optimizer = torch.optim.Adam(net.parameters(), lr=LEARNING_RATE)
#optimizer = torch.optim.SGD(net.parameters(),lr=LEARNING_RATE)
# 定义一个误差计算方法
#loss_func = HuberLossPena(delta=0.1, penalty_weight=5.0)
#loss_func = nn.MSELoss()
loss_func = nn.CrossEntropyLoss() #定义交叉熵损失函数 交叉熵损失函数是用来衡量两个概率分布之间的距离的#nn.MSELoss()
# Define the loss function with Classification Cross-Entropy loss and an optimizer with Adam optimizer


casename='202406-detec-F'
def create_case_folder(case_name):
    if not os.path.exists(case_name):
        os.makedirs(case_name)
create_case_folder("./log/"+casename)
create_case_folder("./result/"+casename)
writer = SummaryWriter("./log/"+casename) #tensorboard

print(net)
writer.add_graph(net, images)
writer.close()
# Out:
# ModResv2(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (sigmoid): Sigmoid()
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=128, out_features=2048, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=128, out_features=2048, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (seblock): SEBlock(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=128, out_features=2048, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (self_attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=2048, out_features=2048, bias=True)
#   )
#   (seblock1): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=256, out_features=16, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=16, out_features=256, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (seblock2): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=32, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=32, out_features=512, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (seblock3): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=64, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=64, out_features=1024, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (seblock4): SEBlock(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=128, bias=False)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=128, out_features=2048, bias=False)
#       (3): Sigmoid()
#     )
#   )
#   (fusion4): MultiScaleFusion(
#     (conv1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1))
#     (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(2048, 2048, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (fusion_conv): Conv2d(8192, 2048, kernel_size=(1, 1), stride=(1, 1))
#     (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (fusion1): MultiScaleFusion(
#     (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (fusion_conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (fc2): Linear(in_features=1024, out_features=24, bias=True)
#   (fc): Linear(in_features=2048, out_features=24, bias=True)
# )

# %% [markdown]
# # EXCUETE MODEL

# %%
if __name__ == "__main__":
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    torch.cuda.empty_cache()
    # Let's build our model
    train(300,device,net)
    print('Finished Training')

    #Epochごとのlossの保存
    #torch.save(net, "./result/"+casename+"/"+casename+".pt")
    # 保存网络中的参数, 速度快，占空间少
    #torch.save(net.state_dict(),'case-1-p.pt')
    #--------------------------------------------------
    #针对上面一般的保存方法，加载的方法分别是：
    # model_dict=torch.load(PATH)
    # model_dict=model.load_state_dict(torch.load(PATH))
    # Test which classes performed well
    valid(net, device, valid_loader, classes)
    # Let's load the model we just created and test the accuracy per label
    # model = net()
    # path = "myFirstModel.pth"
    # model.load_state_dict(torch.load(path))
# Out:
# [Epoch: 1/300] - Step: 10/5970 | Loss: 405.917 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 20/5970 | Loss: 386.339 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 30/5970 | Loss: 381.640 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 40/5970 | Loss: 347.633 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 50/5970 | Loss: 323.425 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 60/5970 | Loss: 356.044 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 70/5970 | Loss: 306.747 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 80/5970 | Loss: 296.654 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 90/5970 | Loss: 263.883 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 100/5970 | Loss: 334.255 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 110/5970 | Loss: 274.986 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 120/5970 | Loss: 334.204 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 130/5970 | Loss: 324.936 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 140/5970 | Loss: 309.938 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 150/5970 | Loss: 300.580 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 160/5970 | Loss: 334.066 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 170/5970 | Loss: 314.611 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 180/5970 | Loss: 311.264 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 190/5970 | Loss: 325.705 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 200/5970 | Loss: 323.760 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 210/5970 | Loss: 308.511 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 220/5970 | Loss: 276.889 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 230/5970 | Loss: 298.503 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 240/5970 | Loss: 313.374 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 250/5970 | Loss: 303.793 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 260/5970 | Loss: 323.899 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 270/5970 | Loss: 316.148 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 280/5970 | Loss: 300.675 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 290/5970 | Loss: 318.802 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 300/5970 | Loss: 324.910 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 310/5970 | Loss: 299.502 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 320/5970 | Loss: 311.911 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 330/5970 | Loss: 339.840 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 340/5970 | Loss: 317.627 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 350/5970 | Loss: 321.388 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 360/5970 | Loss: 325.324 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 370/5970 | Loss: 324.098 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 380/5970 | Loss: 286.138 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 390/5970 | Loss: 330.202 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 400/5970 | Loss: 295.769 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 410/5970 | Loss: 329.366 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 420/5970 | Loss: 320.257 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 430/5970 | Loss: 298.628 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 440/5970 | Loss: 322.804 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 450/5970 | Loss: 329.029 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 460/5970 | Loss: 305.038 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 470/5970 | Loss: 297.683 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 480/5970 | Loss: 313.501 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 490/5970 | Loss: 314.472 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 500/5970 | Loss: 295.986 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 510/5970 | Loss: 338.852 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 520/5970 | Loss: 326.289 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 530/5970 | Loss: 302.480 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 540/5970 | Loss: 327.752 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 550/5970 | Loss: 311.565 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 560/5970 | Loss: 286.908 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 570/5970 | Loss: 303.381 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 580/5970 | Loss: 312.202 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 590/5970 | Loss: 307.594 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 600/5970 | Loss: 325.932 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 610/5970 | Loss: 310.429 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 620/5970 | Loss: 310.880 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 630/5970 | Loss: 290.508 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 640/5970 | Loss: 303.038 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 650/5970 | Loss: 302.223 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 660/5970 | Loss: 317.305 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 670/5970 | Loss: 308.269 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 680/5970 | Loss: 311.852 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 690/5970 | Loss: 314.895 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 700/5970 | Loss: 315.246 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 710/5970 | Loss: 312.444 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 720/5970 | Loss: 290.322 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 730/5970 | Loss: 273.292 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 740/5970 | Loss: 346.874 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 750/5970 | Loss: 303.315 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 760/5970 | Loss: 318.027 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 770/5970 | Loss: 290.425 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 780/5970 | Loss: 308.238 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 790/5970 | Loss: 350.253 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 800/5970 | Loss: 303.172 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 810/5970 | Loss: 305.606 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 820/5970 | Loss: 288.289 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 830/5970 | Loss: 305.295 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 840/5970 | Loss: 297.135 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 850/5970 | Loss: 333.110 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 860/5970 | Loss: 267.102 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 870/5970 | Loss: 295.993 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 880/5970 | Loss: 287.078 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 890/5970 | Loss: 294.105 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 900/5970 | Loss: 307.377 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 910/5970 | Loss: 311.905 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 920/5970 | Loss: 333.904 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 930/5970 | Loss: 320.447 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 940/5970 | Loss: 338.299 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 950/5970 | Loss: 300.570 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 960/5970 | Loss: 308.969 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 970/5970 | Loss: 311.848 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 980/5970 | Loss: 301.545 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 990/5970 | Loss: 324.702 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1000/5970 | Loss: 336.556 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1010/5970 | Loss: 314.052 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1020/5970 | Loss: 304.907 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1030/5970 | Loss: 289.019 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1040/5970 | Loss: 318.101 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1050/5970 | Loss: 308.421 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1060/5970 | Loss: 317.976 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1070/5970 | Loss: 296.224 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1080/5970 | Loss: 268.118 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 1090/5970 | Loss: 310.578 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1100/5970 | Loss: 331.159 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1110/5970 | Loss: 323.289 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1120/5970 | Loss: 318.418 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1130/5970 | Loss: 295.875 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1140/5970 | Loss: 312.206 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1150/5970 | Loss: 319.011 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1160/5970 | Loss: 299.185 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1170/5970 | Loss: 312.634 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1180/5970 | Loss: 302.606 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1190/5970 | Loss: 312.183 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1200/5970 | Loss: 285.038 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1210/5970 | Loss: 295.415 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1220/5970 | Loss: 272.443 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1230/5970 | Loss: 326.311 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1240/5970 | Loss: 318.592 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1250/5970 | Loss: 295.129 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1260/5970 | Loss: 348.008 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1270/5970 | Loss: 302.945 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1280/5970 | Loss: 291.629 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1290/5970 | Loss: 338.223 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1300/5970 | Loss: 288.638 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1310/5970 | Loss: 295.081 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1320/5970 | Loss: 301.223 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1330/5970 | Loss: 282.665 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1340/5970 | Loss: 290.539 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1350/5970 | Loss: 298.880 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 1360/5970 | Loss: 298.709 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1370/5970 | Loss: 312.862 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1380/5970 | Loss: 314.362 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1390/5970 | Loss: 316.188 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1400/5970 | Loss: 299.298 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1410/5970 | Loss: 303.907 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1420/5970 | Loss: 335.078 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1430/5970 | Loss: 323.402 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1440/5970 | Loss: 290.318 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1450/5970 | Loss: 333.639 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1460/5970 | Loss: 308.719 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1470/5970 | Loss: 272.014 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1480/5970 | Loss: 311.801 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1490/5970 | Loss: 291.929 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1500/5970 | Loss: 292.852 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1510/5970 | Loss: 301.530 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1520/5970 | Loss: 322.896 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1530/5970 | Loss: 326.675 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1540/5970 | Loss: 301.897 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1550/5970 | Loss: 295.582 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1560/5970 | Loss: 297.544 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1570/5970 | Loss: 282.212 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1580/5970 | Loss: 312.240 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1590/5970 | Loss: 367.056 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1600/5970 | Loss: 320.086 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1610/5970 | Loss: 296.057 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1620/5970 | Loss: 300.582 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1630/5970 | Loss: 323.889 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1640/5970 | Loss: 321.456 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1650/5970 | Loss: 313.557 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1660/5970 | Loss: 315.448 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1670/5970 | Loss: 299.677 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1680/5970 | Loss: 315.174 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1690/5970 | Loss: 288.786 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 1700/5970 | Loss: 308.771 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1710/5970 | Loss: 300.274 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1720/5970 | Loss: 296.446 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1730/5970 | Loss: 313.254 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1740/5970 | Loss: 303.566 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1750/5970 | Loss: 322.364 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1760/5970 | Loss: 292.179 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1770/5970 | Loss: 288.270 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1780/5970 | Loss: 334.327 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1790/5970 | Loss: 301.216 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1800/5970 | Loss: 330.239 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1810/5970 | Loss: 362.637 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1820/5970 | Loss: 312.543 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1830/5970 | Loss: 325.174 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1840/5970 | Loss: 275.180 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 1850/5970 | Loss: 348.346 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1860/5970 | Loss: 327.183 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1870/5970 | Loss: 290.322 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1880/5970 | Loss: 334.525 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1890/5970 | Loss: 330.946 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1900/5970 | Loss: 327.244 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1910/5970 | Loss: 314.333 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1920/5970 | Loss: 301.156 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1930/5970 | Loss: 297.127 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 1940/5970 | Loss: 303.254 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1950/5970 | Loss: 310.859 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1960/5970 | Loss: 304.089 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1970/5970 | Loss: 302.200 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 1980/5970 | Loss: 299.634 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 1990/5970 | Loss: 325.122 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2000/5970 | Loss: 314.376 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2010/5970 | Loss: 303.879 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2020/5970 | Loss: 307.010 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2030/5970 | Loss: 315.832 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2040/5970 | Loss: 302.880 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2050/5970 | Loss: 290.382 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2060/5970 | Loss: 321.134 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2070/5970 | Loss: 314.626 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2080/5970 | Loss: 331.698 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2090/5970 | Loss: 303.346 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2100/5970 | Loss: 314.552 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2110/5970 | Loss: 300.673 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2120/5970 | Loss: 303.241 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2130/5970 | Loss: 283.878 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2140/5970 | Loss: 309.567 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2150/5970 | Loss: 320.472 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2160/5970 | Loss: 294.048 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2170/5970 | Loss: 322.825 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2180/5970 | Loss: 293.600 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2190/5970 | Loss: 308.246 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2200/5970 | Loss: 291.904 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2210/5970 | Loss: 285.918 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2220/5970 | Loss: 316.378 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2230/5970 | Loss: 304.003 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2240/5970 | Loss: 283.571 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2250/5970 | Loss: 298.902 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2260/5970 | Loss: 309.915 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2270/5970 | Loss: 311.705 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2280/5970 | Loss: 298.271 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2290/5970 | Loss: 319.563 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2300/5970 | Loss: 305.433 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2310/5970 | Loss: 291.616 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2320/5970 | Loss: 325.052 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2330/5970 | Loss: 306.276 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2340/5970 | Loss: 302.904 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2350/5970 | Loss: 305.806 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2360/5970 | Loss: 309.009 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2370/5970 | Loss: 296.351 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2380/5970 | Loss: 287.359 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2390/5970 | Loss: 276.303 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 2400/5970 | Loss: 314.633 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2410/5970 | Loss: 291.361 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2420/5970 | Loss: 303.379 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2430/5970 | Loss: 336.033 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2440/5970 | Loss: 300.667 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2450/5970 | Loss: 288.899 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2460/5970 | Loss: 307.400 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2470/5970 | Loss: 274.644 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2480/5970 | Loss: 306.984 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2490/5970 | Loss: 311.640 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2500/5970 | Loss: 300.858 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2510/5970 | Loss: 287.510 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2520/5970 | Loss: 299.056 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2530/5970 | Loss: 300.904 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2540/5970 | Loss: 304.580 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2550/5970 | Loss: 296.086 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2560/5970 | Loss: 309.750 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2570/5970 | Loss: 297.858 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2580/5970 | Loss: 299.083 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2590/5970 | Loss: 311.034 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2600/5970 | Loss: 281.094 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2610/5970 | Loss: 300.786 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2620/5970 | Loss: 316.358 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2630/5970 | Loss: 294.659 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2640/5970 | Loss: 295.057 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2650/5970 | Loss: 277.607 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2660/5970 | Loss: 297.325 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2670/5970 | Loss: 308.037 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2680/5970 | Loss: 298.077 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2690/5970 | Loss: 294.642 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2700/5970 | Loss: 298.107 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2710/5970 | Loss: 295.691 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2720/5970 | Loss: 281.749 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2730/5970 | Loss: 295.862 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2740/5970 | Loss: 273.531 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2750/5970 | Loss: 297.068 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2760/5970 | Loss: 283.210 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2770/5970 | Loss: 303.710 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2780/5970 | Loss: 309.843 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2790/5970 | Loss: 284.825 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2800/5970 | Loss: 323.223 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2810/5970 | Loss: 304.934 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2820/5970 | Loss: 295.586 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2830/5970 | Loss: 297.723 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 2840/5970 | Loss: 301.966 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2850/5970 | Loss: 300.599 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2860/5970 | Loss: 304.394 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2870/5970 | Loss: 297.481 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2880/5970 | Loss: 309.974 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2890/5970 | Loss: 303.303 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2900/5970 | Loss: 302.645 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2910/5970 | Loss: 299.124 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2920/5970 | Loss: 315.079 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2930/5970 | Loss: 296.888 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2940/5970 | Loss: 304.966 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 2950/5970 | Loss: 291.405 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2960/5970 | Loss: 301.069 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 2970/5970 | Loss: 300.641 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2980/5970 | Loss: 294.361 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 2990/5970 | Loss: 314.561 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3000/5970 | Loss: 307.629 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3010/5970 | Loss: 295.904 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3020/5970 | Loss: 297.335 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3030/5970 | Loss: 304.946 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3040/5970 | Loss: 304.187 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3050/5970 | Loss: 280.783 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 3060/5970 | Loss: 274.841 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3070/5970 | Loss: 289.330 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3080/5970 | Loss: 302.433 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3090/5970 | Loss: 306.147 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3100/5970 | Loss: 300.118 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3110/5970 | Loss: 299.619 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3120/5970 | Loss: 314.929 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3130/5970 | Loss: 298.025 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3140/5970 | Loss: 315.244 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3150/5970 | Loss: 291.184 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3160/5970 | Loss: 302.793 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3170/5970 | Loss: 302.891 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3180/5970 | Loss: 317.430 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 3190/5970 | Loss: 319.192 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3200/5970 | Loss: 296.440 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3210/5970 | Loss: 283.882 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3220/5970 | Loss: 295.641 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3230/5970 | Loss: 302.582 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3240/5970 | Loss: 286.454 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 3250/5970 | Loss: 298.839 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3260/5970 | Loss: 339.804 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3270/5970 | Loss: 306.575 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3280/5970 | Loss: 293.944 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3290/5970 | Loss: 295.356 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3300/5970 | Loss: 299.732 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 3310/5970 | Loss: 291.300 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3320/5970 | Loss: 299.941 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3330/5970 | Loss: 296.995 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3340/5970 | Loss: 303.970 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3350/5970 | Loss: 295.956 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3360/5970 | Loss: 311.591 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3370/5970 | Loss: 288.212 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3380/5970 | Loss: 280.120 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 3390/5970 | Loss: 312.441 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3400/5970 | Loss: 291.463 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3410/5970 | Loss: 301.389 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3420/5970 | Loss: 290.142 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3430/5970 | Loss: 300.599 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3440/5970 | Loss: 301.849 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3450/5970 | Loss: 303.932 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3460/5970 | Loss: 305.590 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3470/5970 | Loss: 286.432 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3480/5970 | Loss: 297.005 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3490/5970 | Loss: 304.467 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3500/5970 | Loss: 291.496 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3510/5970 | Loss: 300.182 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3520/5970 | Loss: 300.270 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3530/5970 | Loss: 274.535 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 3540/5970 | Loss: 306.656 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3550/5970 | Loss: 316.378 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3560/5970 | Loss: 295.656 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3570/5970 | Loss: 292.745 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3580/5970 | Loss: 282.711 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 3590/5970 | Loss: 281.006 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3600/5970 | Loss: 299.117 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3610/5970 | Loss: 303.727 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3620/5970 | Loss: 273.227 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 3630/5970 | Loss: 313.276 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3640/5970 | Loss: 299.450 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3650/5970 | Loss: 287.240 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3660/5970 | Loss: 274.757 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3670/5970 | Loss: 311.448 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3680/5970 | Loss: 303.232 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3690/5970 | Loss: 313.858 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3700/5970 | Loss: 294.571 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3710/5970 | Loss: 302.918 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3720/5970 | Loss: 294.219 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3730/5970 | Loss: 298.515 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3740/5970 | Loss: 320.525 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3750/5970 | Loss: 294.534 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3760/5970 | Loss: 309.804 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3770/5970 | Loss: 281.534 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 3780/5970 | Loss: 311.226 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3790/5970 | Loss: 303.519 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3800/5970 | Loss: 298.232 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3810/5970 | Loss: 289.485 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3820/5970 | Loss: 296.528 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3830/5970 | Loss: 299.520 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3840/5970 | Loss: 299.388 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3850/5970 | Loss: 290.339 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3860/5970 | Loss: 298.507 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3870/5970 | Loss: 304.197 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3880/5970 | Loss: 308.320 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3890/5970 | Loss: 293.270 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3900/5970 | Loss: 296.162 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3910/5970 | Loss: 304.510 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3920/5970 | Loss: 296.370 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3930/5970 | Loss: 297.988 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3940/5970 | Loss: 311.375 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 3950/5970 | Loss: 290.677 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3960/5970 | Loss: 297.291 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3970/5970 | Loss: 284.977 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 3980/5970 | Loss: 330.411 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 3990/5970 | Loss: 328.650 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4000/5970 | Loss: 296.765 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4010/5970 | Loss: 300.393 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4020/5970 | Loss: 304.655 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4030/5970 | Loss: 306.584 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4040/5970 | Loss: 300.819 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4050/5970 | Loss: 294.743 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4060/5970 | Loss: 291.512 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4070/5970 | Loss: 292.876 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4080/5970 | Loss: 311.793 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4090/5970 | Loss: 286.931 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4100/5970 | Loss: 319.886 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4110/5970 | Loss: 293.672 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4120/5970 | Loss: 292.546 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4130/5970 | Loss: 284.605 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4140/5970 | Loss: 304.939 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4150/5970 | Loss: 319.018 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4160/5970 | Loss: 301.677 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4170/5970 | Loss: 290.057 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4180/5970 | Loss: 290.062 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4190/5970 | Loss: 284.594 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4200/5970 | Loss: 293.011 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4210/5970 | Loss: 301.033 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4220/5970 | Loss: 286.972 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4230/5970 | Loss: 275.484 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4240/5970 | Loss: 306.272 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4250/5970 | Loss: 317.602 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4260/5970 | Loss: 290.757 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4270/5970 | Loss: 282.518 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4280/5970 | Loss: 311.533 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4290/5970 | Loss: 284.346 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 4300/5970 | Loss: 298.781 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4310/5970 | Loss: 302.014 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4320/5970 | Loss: 299.564 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4330/5970 | Loss: 281.967 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4340/5970 | Loss: 298.271 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4350/5970 | Loss: 303.377 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4360/5970 | Loss: 284.306 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4370/5970 | Loss: 303.931 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4380/5970 | Loss: 304.503 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4390/5970 | Loss: 299.144 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4400/5970 | Loss: 291.772 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4410/5970 | Loss: 300.531 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4420/5970 | Loss: 275.449 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4430/5970 | Loss: 320.748 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4440/5970 | Loss: 280.024 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4450/5970 | Loss: 276.864 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 4460/5970 | Loss: 278.081 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4470/5970 | Loss: 316.322 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4480/5970 | Loss: 296.453 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4490/5970 | Loss: 271.927 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4500/5970 | Loss: 299.430 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4510/5970 | Loss: 302.122 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4520/5970 | Loss: 303.986 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4530/5970 | Loss: 274.952 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4540/5970 | Loss: 290.633 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4550/5970 | Loss: 283.311 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4560/5970 | Loss: 315.935 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4570/5970 | Loss: 285.077 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4580/5970 | Loss: 299.233 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4590/5970 | Loss: 290.315 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4600/5970 | Loss: 307.970 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4610/5970 | Loss: 303.146 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4620/5970 | Loss: 303.372 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4630/5970 | Loss: 280.828 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4640/5970 | Loss: 299.772 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4650/5970 | Loss: 292.916 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4660/5970 | Loss: 272.903 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4670/5970 | Loss: 286.578 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4680/5970 | Loss: 314.162 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4690/5970 | Loss: 311.436 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4700/5970 | Loss: 292.681 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4710/5970 | Loss: 316.056 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4720/5970 | Loss: 302.093 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4730/5970 | Loss: 299.849 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4740/5970 | Loss: 293.595 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4750/5970 | Loss: 267.052 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 4760/5970 | Loss: 292.500 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4770/5970 | Loss: 319.432 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4780/5970 | Loss: 300.765 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4790/5970 | Loss: 331.868 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4800/5970 | Loss: 293.495 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4810/5970 | Loss: 295.439 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4820/5970 | Loss: 298.596 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4830/5970 | Loss: 291.529 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4840/5970 | Loss: 287.807 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4850/5970 | Loss: 300.664 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4860/5970 | Loss: 291.239 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4870/5970 | Loss: 294.435 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4880/5970 | Loss: 323.768 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4890/5970 | Loss: 292.857 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4900/5970 | Loss: 298.202 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4910/5970 | Loss: 280.011 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4920/5970 | Loss: 289.694 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 4930/5970 | Loss: 302.167 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 4940/5970 | Loss: 334.072 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4950/5970 | Loss: 309.785 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4960/5970 | Loss: 294.860 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4970/5970 | Loss: 306.066 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 4980/5970 | Loss: 286.689 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 4990/5970 | Loss: 297.286 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5000/5970 | Loss: 269.771 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 5010/5970 | Loss: 298.557 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5020/5970 | Loss: 308.769 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5030/5970 | Loss: 289.661 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 5040/5970 | Loss: 301.219 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5050/5970 | Loss: 300.814 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5060/5970 | Loss: 286.539 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5070/5970 | Loss: 298.857 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5080/5970 | Loss: 309.263 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5090/5970 | Loss: 304.071 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5100/5970 | Loss: 285.249 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5110/5970 | Loss: 304.298 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5120/5970 | Loss: 316.738 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5130/5970 | Loss: 301.410 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5140/5970 | Loss: 294.863 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5150/5970 | Loss: 299.827 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5160/5970 | Loss: 283.785 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5170/5970 | Loss: 299.005 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5180/5970 | Loss: 309.059 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5190/5970 | Loss: 315.173 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5200/5970 | Loss: 298.239 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5210/5970 | Loss: 297.257 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5220/5970 | Loss: 287.914 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 5230/5970 | Loss: 297.578 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5240/5970 | Loss: 298.512 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5250/5970 | Loss: 309.427 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5260/5970 | Loss: 275.384 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5270/5970 | Loss: 288.093 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5280/5970 | Loss: 296.934 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5290/5970 | Loss: 295.163 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5300/5970 | Loss: 305.449 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5310/5970 | Loss: 298.640 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5320/5970 | Loss: 307.735 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5330/5970 | Loss: 297.158 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5340/5970 | Loss: 303.929 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5350/5970 | Loss: 298.233 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5360/5970 | Loss: 298.893 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5370/5970 | Loss: 301.318 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5380/5970 | Loss: 300.108 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5390/5970 | Loss: 306.555 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5400/5970 | Loss: 295.905 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5410/5970 | Loss: 297.611 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5420/5970 | Loss: 291.028 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5430/5970 | Loss: 307.275 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5440/5970 | Loss: 280.819 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5450/5970 | Loss: 270.254 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5460/5970 | Loss: 295.803 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5470/5970 | Loss: 284.725 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5480/5970 | Loss: 290.982 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5490/5970 | Loss: 288.545 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5500/5970 | Loss: 297.086 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5510/5970 | Loss: 294.561 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5520/5970 | Loss: 260.643 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 5530/5970 | Loss: 297.778 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5540/5970 | Loss: 313.276 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5550/5970 | Loss: 295.834 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5560/5970 | Loss: 279.914 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5570/5970 | Loss: 315.164 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5580/5970 | Loss: 277.663 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5590/5970 | Loss: 284.860 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5600/5970 | Loss: 339.172 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5610/5970 | Loss: 297.492 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5620/5970 | Loss: 301.757 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5630/5970 | Loss: 291.237 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5640/5970 | Loss: 310.495 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5650/5970 | Loss: 289.183 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5660/5970 | Loss: 301.260 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5670/5970 | Loss: 296.538 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5680/5970 | Loss: 306.932 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5690/5970 | Loss: 307.116 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5700/5970 | Loss: 290.267 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 5710/5970 | Loss: 303.521 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5720/5970 | Loss: 297.896 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5730/5970 | Loss: 286.093 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5740/5970 | Loss: 324.744 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5750/5970 | Loss: 282.607 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5760/5970 | Loss: 268.773 | Accuracy: 0.400
# [Epoch: 1/300] - Step: 5770/5970 | Loss: 277.802 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 5780/5970 | Loss: 344.622 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5790/5970 | Loss: 306.367 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5800/5970 | Loss: 295.009 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5810/5970 | Loss: 301.904 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5820/5970 | Loss: 286.470 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5830/5970 | Loss: 301.979 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5840/5970 | Loss: 288.455 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5850/5970 | Loss: 298.427 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5860/5970 | Loss: 307.662 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5870/5970 | Loss: 293.044 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5880/5970 | Loss: 315.350 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5890/5970 | Loss: 300.421 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5900/5970 | Loss: 297.890 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5910/5970 | Loss: 321.883 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5920/5970 | Loss: 292.560 | Accuracy: 0.000
# [Epoch: 1/300] - Step: 5930/5970 | Loss: 326.264 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5940/5970 | Loss: 291.124 | Accuracy: 0.200
# [Epoch: 1/300] - Step: 5950/5970 | Loss: 290.601 | Accuracy: 0.300
# [Epoch: 1/300] - Step: 5960/5970 | Loss: 288.491 | Accuracy: 0.100
# [Epoch: 1/300] - Step: 5970/5970 | Loss: 311.733 | Accuracy: 0.000
# Accuracy:  0.10491803278688525
# Model saved!
# [Epoch: 2/300] - Step: 10/5970 | Loss: 269.875 | Accuracy: 0.400
# [Epoch: 2/300] - Step: 20/5970 | Loss: 281.886 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 30/5970 | Loss: 311.555 | Accuracy: 0.300
# [Epoch: 2/300] - Step: 40/5970 | Loss: 308.404 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 50/5970 | Loss: 306.344 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 60/5970 | Loss: 278.167 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 70/5970 | Loss: 299.146 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 80/5970 | Loss: 297.094 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 90/5970 | Loss: 288.278 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 100/5970 | Loss: 287.214 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 110/5970 | Loss: 304.654 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 120/5970 | Loss: 318.821 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 130/5970 | Loss: 279.621 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 140/5970 | Loss: 296.062 | Accuracy: 0.300
# [Epoch: 2/300] - Step: 150/5970 | Loss: 306.186 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 160/5970 | Loss: 289.048 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 170/5970 | Loss: 288.991 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 180/5970 | Loss: 289.523 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 190/5970 | Loss: 327.914 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 200/5970 | Loss: 295.107 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 210/5970 | Loss: 309.772 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 220/5970 | Loss: 285.298 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 230/5970 | Loss: 292.433 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 240/5970 | Loss: 308.171 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 250/5970 | Loss: 296.358 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 260/5970 | Loss: 313.680 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 270/5970 | Loss: 295.162 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 280/5970 | Loss: 296.308 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 290/5970 | Loss: 312.084 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 300/5970 | Loss: 303.189 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 310/5970 | Loss: 279.199 | Accuracy: 0.300
# [Epoch: 2/300] - Step: 320/5970 | Loss: 273.191 | Accuracy: 0.400
# [Epoch: 2/300] - Step: 330/5970 | Loss: 291.648 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 340/5970 | Loss: 298.087 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 350/5970 | Loss: 301.788 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 360/5970 | Loss: 302.480 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 370/5970 | Loss: 302.540 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 380/5970 | Loss: 296.575 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 390/5970 | Loss: 292.759 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 400/5970 | Loss: 289.914 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 410/5970 | Loss: 308.421 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 420/5970 | Loss: 286.661 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 430/5970 | Loss: 288.557 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 440/5970 | Loss: 303.293 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 450/5970 | Loss: 323.256 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 460/5970 | Loss: 304.231 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 470/5970 | Loss: 287.826 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 480/5970 | Loss: 290.950 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 490/5970 | Loss: 290.830 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 500/5970 | Loss: 278.878 | Accuracy: 0.300
# [Epoch: 2/300] - Step: 510/5970 | Loss: 315.993 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 520/5970 | Loss: 310.467 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 530/5970 | Loss: 303.745 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 540/5970 | Loss: 308.660 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 550/5970 | Loss: 302.206 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 560/5970 | Loss: 305.068 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 570/5970 | Loss: 310.338 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 580/5970 | Loss: 292.792 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 590/5970 | Loss: 290.402 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 600/5970 | Loss: 293.325 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 610/5970 | Loss: 323.639 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 620/5970 | Loss: 307.320 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 630/5970 | Loss: 309.464 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 640/5970 | Loss: 284.744 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 650/5970 | Loss: 297.498 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 660/5970 | Loss: 279.402 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 670/5970 | Loss: 295.702 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 680/5970 | Loss: 251.612 | Accuracy: 0.500
# [Epoch: 2/300] - Step: 690/5970 | Loss: 297.380 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 700/5970 | Loss: 311.481 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 710/5970 | Loss: 305.061 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 720/5970 | Loss: 279.463 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 730/5970 | Loss: 314.500 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 740/5970 | Loss: 293.312 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 750/5970 | Loss: 300.527 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 760/5970 | Loss: 288.836 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 770/5970 | Loss: 303.904 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 780/5970 | Loss: 298.478 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 790/5970 | Loss: 291.894 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 800/5970 | Loss: 300.635 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 810/5970 | Loss: 297.897 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 820/5970 | Loss: 302.759 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 830/5970 | Loss: 282.739 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 840/5970 | Loss: 312.991 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 850/5970 | Loss: 286.441 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 860/5970 | Loss: 291.772 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 870/5970 | Loss: 296.917 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 880/5970 | Loss: 274.200 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 890/5970 | Loss: 303.023 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 900/5970 | Loss: 304.907 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 910/5970 | Loss: 277.184 | Accuracy: 0.300
# [Epoch: 2/300] - Step: 920/5970 | Loss: 297.855 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 930/5970 | Loss: 310.801 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 940/5970 | Loss: 301.385 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 950/5970 | Loss: 297.740 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 960/5970 | Loss: 301.424 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 970/5970 | Loss: 313.362 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 980/5970 | Loss: 314.392 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 990/5970 | Loss: 289.119 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 1000/5970 | Loss: 297.050 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 1010/5970 | Loss: 300.390 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1020/5970 | Loss: 327.580 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 1030/5970 | Loss: 282.436 | Accuracy: 0.400
# [Epoch: 2/300] - Step: 1040/5970 | Loss: 312.282 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1050/5970 | Loss: 299.123 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1060/5970 | Loss: 297.752 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 1070/5970 | Loss: 292.973 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1080/5970 | Loss: 284.041 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1090/5970 | Loss: 304.576 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 1100/5970 | Loss: 293.153 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 1110/5970 | Loss: 293.398 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1120/5970 | Loss: 293.753 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1130/5970 | Loss: 309.757 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 1140/5970 | Loss: 287.178 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 1150/5970 | Loss: 285.852 | Accuracy: 0.300
# [Epoch: 2/300] - Step: 1160/5970 | Loss: 299.945 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1170/5970 | Loss: 299.174 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1180/5970 | Loss: 297.250 | Accuracy: 0.100
# [Epoch: 2/300] - Step: 1190/5970 | Loss: 315.407 | Accuracy: 0.000
# [Epoch: 2/300] - Step: 1200/5970 | Loss: 289.866 | Accuracy: 0.200
# [Epoch: 2/300] - Step: 1210/5970 | Loss: 304.561 | Accuracy: 0.100
# ...
# [Epoch: 8/300] - Step: 1980/5970 | Loss: 296.417 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 1990/5970 | Loss: 299.727 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2000/5970 | Loss: 286.915 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2010/5970 | Loss: 282.159 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2020/5970 | Loss: 336.518 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2030/5970 | Loss: 295.471 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2040/5970 | Loss: 336.882 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2050/5970 | Loss: 295.032 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2060/5970 | Loss: 285.568 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2070/5970 | Loss: 288.298 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2080/5970 | Loss: 287.554 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2090/5970 | Loss: 287.377 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2100/5970 | Loss: 286.174 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2110/5970 | Loss: 295.164 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2120/5970 | Loss: 287.933 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2130/5970 | Loss: 323.885 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2140/5970 | Loss: 311.443 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2150/5970 | Loss: 291.140 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2160/5970 | Loss: 304.779 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2170/5970 | Loss: 298.369 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2180/5970 | Loss: 295.659 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2190/5970 | Loss: 302.372 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2200/5970 | Loss: 291.180 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2210/5970 | Loss: 282.520 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2220/5970 | Loss: 315.809 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2230/5970 | Loss: 297.838 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2240/5970 | Loss: 288.760 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2250/5970 | Loss: 307.813 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2260/5970 | Loss: 290.482 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2270/5970 | Loss: 294.257 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2280/5970 | Loss: 292.588 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2290/5970 | Loss: 267.521 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 2300/5970 | Loss: 333.197 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2310/5970 | Loss: 283.695 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2320/5970 | Loss: 269.427 | Accuracy: 0.400
# [Epoch: 8/300] - Step: 2330/5970 | Loss: 302.278 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2340/5970 | Loss: 292.296 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2350/5970 | Loss: 315.417 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2360/5970 | Loss: 317.777 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2370/5970 | Loss: 301.978 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2380/5970 | Loss: 272.053 | Accuracy: 0.400
# [Epoch: 8/300] - Step: 2390/5970 | Loss: 301.080 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2400/5970 | Loss: 298.618 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2410/5970 | Loss: 294.545 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2420/5970 | Loss: 303.368 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2430/5970 | Loss: 309.607 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2440/5970 | Loss: 291.502 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2450/5970 | Loss: 287.056 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2460/5970 | Loss: 300.420 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2470/5970 | Loss: 291.938 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2480/5970 | Loss: 296.101 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2490/5970 | Loss: 282.219 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2500/5970 | Loss: 277.263 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2510/5970 | Loss: 297.713 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2520/5970 | Loss: 299.683 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2530/5970 | Loss: 290.701 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2540/5970 | Loss: 300.511 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2550/5970 | Loss: 279.307 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2560/5970 | Loss: 290.914 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2570/5970 | Loss: 283.948 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 2580/5970 | Loss: 287.414 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2590/5970 | Loss: 316.502 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2600/5970 | Loss: 290.947 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2610/5970 | Loss: 290.608 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2620/5970 | Loss: 294.889 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2630/5970 | Loss: 299.969 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2640/5970 | Loss: 293.889 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2650/5970 | Loss: 284.838 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2660/5970 | Loss: 292.158 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2670/5970 | Loss: 290.520 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2680/5970 | Loss: 268.399 | Accuracy: 0.400
# [Epoch: 8/300] - Step: 2690/5970 | Loss: 325.449 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2700/5970 | Loss: 296.972 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2710/5970 | Loss: 302.899 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2720/5970 | Loss: 300.455 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2730/5970 | Loss: 318.450 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2740/5970 | Loss: 284.504 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2750/5970 | Loss: 301.980 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2760/5970 | Loss: 296.032 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2770/5970 | Loss: 275.042 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 2780/5970 | Loss: 293.696 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2790/5970 | Loss: 282.062 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2800/5970 | Loss: 306.847 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2810/5970 | Loss: 333.828 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2820/5970 | Loss: 290.946 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2830/5970 | Loss: 308.654 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2840/5970 | Loss: 308.796 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2850/5970 | Loss: 299.482 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2860/5970 | Loss: 285.070 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2870/5970 | Loss: 303.306 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2880/5970 | Loss: 273.274 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2890/5970 | Loss: 292.353 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2900/5970 | Loss: 302.820 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2910/5970 | Loss: 310.847 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2920/5970 | Loss: 301.621 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2930/5970 | Loss: 280.954 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 2940/5970 | Loss: 300.197 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2950/5970 | Loss: 284.592 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 2960/5970 | Loss: 319.561 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 2970/5970 | Loss: 302.829 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 2980/5970 | Loss: 263.778 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 2990/5970 | Loss: 305.110 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3000/5970 | Loss: 295.571 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3010/5970 | Loss: 292.755 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3020/5970 | Loss: 284.366 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3030/5970 | Loss: 299.996 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3040/5970 | Loss: 306.670 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3050/5970 | Loss: 283.582 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3060/5970 | Loss: 284.030 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3070/5970 | Loss: 291.624 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3080/5970 | Loss: 306.737 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3090/5970 | Loss: 303.349 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3100/5970 | Loss: 303.183 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3110/5970 | Loss: 301.608 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3120/5970 | Loss: 278.077 | Accuracy: 0.400
# [Epoch: 8/300] - Step: 3130/5970 | Loss: 275.914 | Accuracy: 0.400
# [Epoch: 8/300] - Step: 3140/5970 | Loss: 284.926 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3150/5970 | Loss: 305.012 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3160/5970 | Loss: 273.475 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 3170/5970 | Loss: 311.345 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3180/5970 | Loss: 326.361 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3190/5970 | Loss: 293.706 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3200/5970 | Loss: 284.358 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3210/5970 | Loss: 309.653 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3220/5970 | Loss: 309.750 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3230/5970 | Loss: 318.762 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3240/5970 | Loss: 315.081 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3250/5970 | Loss: 279.444 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3260/5970 | Loss: 279.470 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 3270/5970 | Loss: 306.604 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3280/5970 | Loss: 273.473 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 3290/5970 | Loss: 287.763 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3300/5970 | Loss: 313.474 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3310/5970 | Loss: 286.999 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3320/5970 | Loss: 284.517 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3330/5970 | Loss: 280.250 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3340/5970 | Loss: 258.029 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3350/5970 | Loss: 308.995 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3360/5970 | Loss: 322.775 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3370/5970 | Loss: 290.228 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3380/5970 | Loss: 291.179 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3390/5970 | Loss: 306.054 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3400/5970 | Loss: 304.741 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3410/5970 | Loss: 307.353 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3420/5970 | Loss: 286.953 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3430/5970 | Loss: 308.655 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3440/5970 | Loss: 292.018 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3450/5970 | Loss: 274.191 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 3460/5970 | Loss: 307.709 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3470/5970 | Loss: 299.031 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3480/5970 | Loss: 295.554 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3490/5970 | Loss: 286.229 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3500/5970 | Loss: 299.039 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3510/5970 | Loss: 290.277 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3520/5970 | Loss: 298.470 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3530/5970 | Loss: 280.454 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3540/5970 | Loss: 290.935 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3550/5970 | Loss: 296.157 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3560/5970 | Loss: 278.286 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3570/5970 | Loss: 296.276 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3580/5970 | Loss: 300.600 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3590/5970 | Loss: 289.272 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3600/5970 | Loss: 304.671 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3610/5970 | Loss: 292.194 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3620/5970 | Loss: 305.549 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3630/5970 | Loss: 282.825 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 3640/5970 | Loss: 290.719 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3650/5970 | Loss: 302.358 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3660/5970 | Loss: 302.265 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3670/5970 | Loss: 282.230 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3680/5970 | Loss: 295.832 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3690/5970 | Loss: 305.703 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3700/5970 | Loss: 296.996 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3710/5970 | Loss: 279.319 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3720/5970 | Loss: 294.410 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3730/5970 | Loss: 310.767 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3740/5970 | Loss: 333.249 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3750/5970 | Loss: 308.595 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3760/5970 | Loss: 306.207 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3770/5970 | Loss: 302.330 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3780/5970 | Loss: 301.021 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3790/5970 | Loss: 298.811 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3800/5970 | Loss: 282.095 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 3810/5970 | Loss: 302.926 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3820/5970 | Loss: 296.313 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3830/5970 | Loss: 330.012 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3840/5970 | Loss: 311.154 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3850/5970 | Loss: 293.394 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3860/5970 | Loss: 281.596 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3870/5970 | Loss: 294.769 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3880/5970 | Loss: 307.287 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3890/5970 | Loss: 333.908 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3900/5970 | Loss: 290.046 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3910/5970 | Loss: 279.921 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3920/5970 | Loss: 291.372 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3930/5970 | Loss: 291.462 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3940/5970 | Loss: 301.025 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 3950/5970 | Loss: 289.060 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 3960/5970 | Loss: 314.053 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3970/5970 | Loss: 282.222 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 3980/5970 | Loss: 314.861 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 3990/5970 | Loss: 294.926 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 4000/5970 | Loss: 329.466 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4010/5970 | Loss: 299.807 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4020/5970 | Loss: 308.753 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4030/5970 | Loss: 308.840 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4040/5970 | Loss: 306.891 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4050/5970 | Loss: 300.101 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4060/5970 | Loss: 286.835 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4070/5970 | Loss: 293.389 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4080/5970 | Loss: 281.276 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 4090/5970 | Loss: 287.086 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 4100/5970 | Loss: 309.016 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4110/5970 | Loss: 282.351 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 4120/5970 | Loss: 297.706 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4130/5970 | Loss: 280.967 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 4140/5970 | Loss: 284.625 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4150/5970 | Loss: 296.071 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 4160/5970 | Loss: 305.014 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4170/5970 | Loss: 296.954 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4180/5970 | Loss: 292.081 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4190/5970 | Loss: 305.598 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4200/5970 | Loss: 320.258 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4210/5970 | Loss: 289.770 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4220/5970 | Loss: 297.381 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4230/5970 | Loss: 313.142 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4240/5970 | Loss: 306.624 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4250/5970 | Loss: 295.953 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4260/5970 | Loss: 281.121 | Accuracy: 0.300
# [Epoch: 8/300] - Step: 4270/5970 | Loss: 304.683 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4280/5970 | Loss: 301.033 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4290/5970 | Loss: 295.767 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 4300/5970 | Loss: 297.024 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4310/5970 | Loss: 300.619 | Accuracy: 0.100
# [Epoch: 8/300] - Step: 4320/5970 | Loss: 305.507 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4330/5970 | Loss: 315.357 | Accuracy: 0.000
# [Epoch: 8/300] - Step: 4340/5970 | Loss: 293.218 | Accuracy: 0.200
# [Epoch: 8/300] - Step: 4350/5970 | Loss: 318.187 | Accuracy: 0.000

# %%
import time
net.to(device)
net.eval()
predictions = []
label1 = []
dataiter=iter(valid_loader)
images, label0 = dataiter.__next__()

start_time = time.process_time()
with torch.no_grad():
        images = images.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        predictions.extend(predicted.cpu().numpy())
end_time = time.process_time()

print("Prediction completed in: ", (end_time - start_time), " seconds")

print(predictions, label0)
# Out:
# Prediction completed in:  0.3873730990162585  seconds
# [22] tensor([13])
